# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util
import nltk

import re
import requests
import pandas as pd
import numpy as np
import json
import os
import dotenv
import sys
import lyricsgenius
import base64
from glob import glob
sys.tracebacklimit = 0 # turn off the error tracebacks

# %% [markdown]
# # Connect to Spotify and Genius APIS

# %%
dotenv.load_dotenv()
geniusclientid = os.getenv('genius_id')
geniusclientsecret = os.getenv('genius_secret')
geniusclientaccesstoken = os.getenv('genius_token')
spotifyclientid = os.getenv('spot_id')
spotifyclientsecret = os.getenv('spot_secret')

# %%
genius = lyricsgenius.Genius(geniusclientaccesstoken)

# %%
# r = requests.get('https://httpbin.org/user-agent')
# useragent = json.loads(r.text)['user-agent']
# headers = {'User-Agent':useragent,
#            'From':'mtv2eva@virginia.edu'}

# %%
# root = 'https://api.genius.com'
# endpoint = '/search?'
# parameters = {'access_token':geniusclientaccesstoken,
#               'q':'Pink Floyd'}
# r = requests.get(root+endpoint, params=parameters, headers=headers, timeout=30)

# myjson = json.loads(r.text)
# myjson

# %%
username = 'michael_vaden'

redirect_uri= 'https://www.virginia.edu/'

client_credentials_manager = SpotifyClientCredentials(client_id=spotifyclientid, client_secret=spotifyclientsecret)

scope = "playlist-modify-public playlist-modify-private playlist-read-private playlist-read-collaborative user-library-modify"

token = util.prompt_for_user_token(username, scope, spotifyclientid, spotifyclientsecret, redirect_uri, show_dialog=True)

sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager, auth=token)

# %% [markdown]
# # Get Songs, Stats, and Lyrics from each decade playlist

# %%
def get_tracks(user, playlist):
        myjson = sp.user_playlist_tracks(user, playlist)

        tracks = myjson['items']

        while myjson['next']:
            myjson = sp.next(myjson)
            tracks.extend(myjson['items'])

        return pd.json_normalize(tracks)

def get_tracks_from_url(username, url):
    playlist_URI = url.split("/")[-1].split("?")[0]

    return get_tracks(username, playlist_URI)

def add_song_features(df):
    song_features = pd.DataFrame()
    for track in df['track.uri']:
        song_features = pd.concat([song_features, pd.json_normalize(sp.audio_features(track))])

    return df.merge(song_features, left_on='track.uri', right_on='uri')

def add_song_genres(df):
    df['genres'] = [sp.artist(pd.json_normalize(df['track.artists'][x])['id'][0])['genres'] for x in range(df.shape[0])]
    return df

# %%
# All out 70s
playlist_link_70s = 'https://open.spotify.com/playlist/37i9dQZF1DWTJ7xPn4vNaz?si=1c451c032af84894'

# All Out 80s
playlist_link_80s = 'https://open.spotify.com/playlist/37i9dQZF1DX4UtSsGT1Sbe?si=8144b29335e74604'

# All Out 90s
playlist_link_90s = 'https://open.spotify.com/playlist/37i9dQZF1DXbTxeAdrVG2l?si=98353266ac23448a'

# All Out 2000s
playlist_link_2000s = 'https://open.spotify.com/playlist/37i9dQZF1DX4o1oenSJRJd?si=141c98a067094ac9'

# All Out 2010s
playlist_link_2010s = 'https://open.spotify.com/playlist/37i9dQZF1DX5Ejj0EkURtP?si=292a3ad73e854085'

# All Out 2020s
playlist_link_2020s = 'https://open.spotify.com/playlist/37i9dQZF1DX2M1RktxUUHG?si=d19a9dc9fc14439d'

# %%
songs_70s = get_tracks_from_url(username, playlist_link_70s)
songs_70s = add_song_features(songs_70s)
songs_70s = add_song_genres(songs_70s)

# %%
songs_80s = get_tracks_from_url(username, playlist_link_80s)
songs_80s = add_song_features(songs_80s)
songs_80s = add_song_genres(songs_80s)

# %%
songs_90s = get_tracks_from_url(username, playlist_link_90s)
songs_90s = add_song_features(songs_90s)
songs_90s = add_song_genres(songs_90s)

# %%
songs_2000s = get_tracks_from_url(username, playlist_link_2000s)
songs_2000s = add_song_features(songs_2000s)
songs_2000s = add_song_genres(songs_2000s)

# %%
songs_2010s = get_tracks_from_url(username, playlist_link_2010s)
songs_2010s = add_song_features(songs_2010s)
songs_2010s = add_song_genres(songs_2010s)

# %%
songs_2020s = get_tracks_from_url(username, playlist_link_2020s)
songs_2020s = add_song_features(songs_2020s)
songs_2020s = add_song_genres(songs_2020s)

# %%
songs_2020s.columns
# Out:
# Index(['added_at', 'is_local', 'primary_color',
#        'added_by.external_urls.spotify', 'added_by.href', 'added_by.id',
#        'added_by.type', 'added_by.uri', 'track.preview_url',
#        'track.available_markets', 'track.explicit', 'track.type',
#        'track.episode', 'track.track', 'track.album.available_markets',
#        'track.album.type', 'track.album.album_type', 'track.album.href',
#        'track.album.id', 'track.album.images', 'track.album.name',
#        'track.album.release_date', 'track.album.release_date_precision',
#        'track.album.uri', 'track.album.artists',
#        'track.album.external_urls.spotify', 'track.album.total_tracks',
#        'track.artists', 'track.disc_number', 'track.track_number',
#        'track.duration_ms', 'track.external_ids.isrc',
#        'track.external_urls.spotify', 'track.href', 'track.id', 'track.name',
#        'track.popularity', 'track.uri', 'track.is_local',
#        'video_thumbnail.url', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url',
#        'duration_ms', 'time_signature', 'genres'],
#       dtype='object')

# %%
songs_70s_filtered = songs_70s[['track.artists', 'track.duration_ms', 'track.id', 'track.name', 'track.popularity', 'danceability', 'energy', 'key', 'loudness', \
             'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature', 'genres']]

songs_70s_filtered['track.artists'] = songs_70s_filtered['track.artists'].apply(lambda x: x[0]['name'])

songs_80s_filtered = songs_80s[['track.artists', 'track.duration_ms', 'track.id', 'track.name', 'track.popularity', 'danceability', 'energy', 'key', 'loudness', \
             'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature', 'genres']]

songs_80s_filtered['track.artists'] = songs_80s_filtered['track.artists'].apply(lambda x: x[0]['name'])

songs_90s_filtered = songs_90s[['track.artists', 'track.duration_ms', 'track.id', 'track.name', 'track.popularity', 'danceability', 'energy', 'key', 'loudness', \
             'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature', 'genres']]
songs_90s_filtered['track.artists'] = songs_90s_filtered['track.artists'].apply(lambda x: x[0]['name'])

songs_2000s_filtered = songs_2000s[['track.artists', 'track.duration_ms', 'track.id', 'track.name', 'track.popularity', 'danceability', 'energy', 'key', 'loudness', \
             'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature', 'genres']]
songs_2000s_filtered['track.artists'] = songs_2000s_filtered['track.artists'].apply(lambda x: x[0]['name'])

songs_2010s_filtered = songs_2010s[['track.artists', 'track.duration_ms', 'track.id', 'track.name', 'track.popularity', 'danceability', 'energy', 'key', 'loudness', \
             'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature', 'genres']]
songs_2010s_filtered['track.artists'] = songs_2010s_filtered['track.artists'].apply(lambda x: x[0]['name'])

songs_2020s_filtered = songs_2020s[['track.artists', 'track.duration_ms', 'track.id', 'track.name', 'track.popularity', 'danceability', 'energy', 'key', 'loudness', \
             'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature', 'genres']]
songs_2020s_filtered['track.artists'] = songs_2020s_filtered['track.artists'].apply(lambda x: x[0]['name'])

# %%
songs_2020s_filtered
# Out:
#     track.artists  track.duration_ms                track.id  \
# 0            RAYE             272373  5mHdCZtVyb4DcJw8799hZp
# 1      Noah Kahan             182346  0mflMxspEfB0VbI1kyLiAv
# 2      Sam Fender             297933  39yxhEuYmm24botBP0O8sx
# 3     Tame Impala             237800  5hM5arv9KDbCHS0k9uqwjr
# 4      Zach Bryan             228013  3WMj8moIAXJhHsyLaqIIHI
# ..            ...                ...                     ...
# 145     21 Savage             193591  6pcywuOeGGWeOQzdUyti6k
# 146   Roddy Ricch             196652  0nbXyq5TXYPCO7pr3N8S4I
# 147         S1mba             167916  4slSrbTK1sNK4I1mDYEthf
# 148     Pop Smoke             160000  1tkg4EHVoqnhR6iFEXb60y
# 149       KAROL G             201920  0dKg2vGC1hFqcK5LGTaKzX
#
#                   track.name  track.popularity  danceability  energy  key  \
# 0                  Escapism.                81         0.538   0.742    2
# 1               Stick Season                94         0.664   0.500    9
# 2      Seventeen Going Under                37         0.479   0.870    1
# 3                 Borderline                82         0.621   0.873    5
# 4    Something in the Orange                88         0.369   0.192    4
# ..                       ...               ...           ...     ...  ...
# 145          Glock In My Lap                83         0.847   0.733   10
# 146                  The Box                83         0.896   0.586   10
# 147        Rover (feat. DTG)                69         0.613   0.624   11
# 148  What You Know Bout Love                79         0.709   0.548   10
# 149                     Tusa                70         0.799   0.701    2
#
#      loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0      -5.355     1       0.1140       0.13800          0.000047    0.0934
# 1      -6.935     1       0.0651       0.79900          0.000000    0.0966
# 2      -4.876     1       0.0366       0.00788          0.004190    0.0826
# 3      -3.067     0       0.0369       0.04060          0.000009    0.0824
# 4     -12.151     0       0.0400       0.55500          0.000008    0.0954
# ..        ...   ...          ...           ...               ...       ...
# 145    -6.439     0       0.1600       0.00574          0.000010    0.1510
# 146    -6.687     0       0.0559       0.10400          0.000000    0.7900
# 147    -6.660     0       0.2060       0.49600          0.000000    0.2830
# 148    -8.493     1       0.3530       0.65000          0.000002    0.1330
# 149    -3.272     1       0.2820       0.30900          0.000074    0.0514
#
#      valence    tempo  time_signature  \
# 0      0.250   96.107               4
# 1      0.801  117.896               4
# 2      0.587  161.964               4
# 3      0.873   97.960               4
# 4      0.148  175.212               3
# ..       ...      ...             ...
# 145    0.202  130.029               4
# 146    0.642  116.971               4
# 147    0.803   62.948               5
# 148    0.543   83.995               4
# 149    0.607  100.946               4
#
#                                                 genres
# 0                        [uk contemporary r&b, uk pop]
# 1                                         [pov: indie]
# 2              [modern rock, north east england indie]
# 3    [australian psych, modern rock, neo-psychedeli...
# 4                           [classic oklahoma country]
# ..                                                 ...
# 145                        [atl hip hop, hip hop, rap]
# 146                           [melodic rap, rap, trap]
# 147                                        [afroswing]
# 148                              [brooklyn drill, rap]
# 149  [reggaeton, reggaeton colombiano, trap latino,...
#
# [150 rows x 18 columns]

# %%
def add_lyrics_to_df(song_df):

    lyrics_vector = []
    for i in range(len(song_df)):
        try:
            find_song = genius.search_song(song_df['track.name'][i], song_df['track.artists'][i])
            song_lyrics = find_song.lyrics

        except:
            song_lyrics = ''
        
        if len(song_lyrics.split()) > 1000:
            song_lyrics = ''

        # regex taken from Ryan Lipps' Repository for Text Analytics
        song_lyrics = re.sub(fr'(?i)\d+(.*?lyrics)', '', song_lyrics)
        song_lyrics = re.sub(fr'(?<!\s)Embed$', '', song_lyrics)
        song_lyrics = re.sub(fr'(?i)you might also like', '', song_lyrics)
        song_lyrics = re.sub(fr'(?i)See\s(.*?)\sLiveGet\stickets\sas\slow\sas\s\$\d+', '', song_lyrics)
        song_lyrics = re.sub(fr'(?i)\[instrumental (.*?)\]', '', song_lyrics)
        song_lyrics = re.sub(fr'(?i)\[interlude\]', '', song_lyrics)
        song_lyrics = re.sub(fr'(?i)\w+(\d+)\b', '', song_lyrics)
        song_lyrics = re.sub(fr'[.,;:"?!()-]\d+', '', song_lyrics)
        song_lyrics = re.sub(fr'  ', '', song_lyrics)
        song_lyrics = re.sub(fr'  ', '', song_lyrics)
        song_lyrics = re.sub(fr'  ', '', song_lyrics)
        song_lyrics = re.sub(fr'\[(.*?)\]', '', song_lyrics)
        song_lyrics = re.sub(fr'\s\s', '\n', song_lyrics)

        if '•' in song_lyrics: # accounting for weird list output
            song_lyrics = ''
        lyrics_vector.append(song_lyrics)
    
    song_df['lyrics'] = lyrics_vector

    return song_df

# %%
# songs_70s_with_lyrics = add_lyrics_to_df(songs_70s_filtered)
# Out:
# Searching for "Dreams - 2004 Remaster" by Fleetwood Mac...
# Done.
# Searching for "Tiny Dancer" by Elton John...
# Done.
# Searching for "Vienna" by Billy Joel...
# Done.
# Searching for "Baba O'Riley" by The Who...
# Done.
# Searching for "Right Down the Line" by Gerry Rafferty...
# Done.
# Searching for "Heroes - 2017 Remaster" by David Bowie...
# Done.
# Searching for "Rocket Man (I Think It's Going To Be A Long, Long Time)" by Elton John...
# Done.
# Searching for "The Chain - 2004 Remaster" by Fleetwood Mac...
# Done.
# Searching for "Wish You Were Here" by Pink Floyd...
# Done.
# Searching for "Ain't No Sunshine" by Bill Withers...
# Searching for "Wild World" by Yusuf / Cat Stevens...
# Done.
# Searching for "American Pie" by Don McLean...
# Done.
# Searching for "Go Your Own Way - 2004 Remaster" by Fleetwood Mac...
# Done.
# Searching for "A Horse with No Name" by America...
# Done.
# Searching for "Beast Of Burden - Remastered 1994" by The Rolling Stones...
# Done.
# Searching for "Rich Girl" by Daryl Hall & John Oates...
# Done.
# Searching for "Message In A Bottle" by The Police...
# Done.
# Searching for "Lovely Day" by Bill Withers...
# Searching for "Stuck In The Middle With You" by Stealers Wheel...
# Searching for "Mr. Blue Sky" by Electric Light Orchestra...
# Searching for "More Than a Feeling" by Boston...
# Done.
# Searching for "Walk On the Wild Side" by Lou Reed...
# Done.
# Searching for "Landslide" by Fleetwood Mac...
# Searching for "Sultans of Swing" by Dire Straits...
# Done.
# Searching for "The Passenger" by Iggy Pop...
# Done.
# Searching for "Roxanne" by The Police...
# Done.
# Searching for "Piano Man" by Billy Joel...
# Done.
# Searching for "Starman - 2012 Remaster" by David Bowie...
# Done.
# Searching for "Wild Horses - 2009 Mix" by The Rolling Stones...
# Done.
# Searching for "Your Song" by Elton John...
# Done.
# Searching for "Heart of Gold - 2009 Remaster" by Neil Young...
# Done.
# Searching for "Dancing in the Moonlight" by King Harvest...
# Done.
# Searching for "Hold the Line" by TOTO...
# Searching for "(Don't Fear) The Reaper" by Blue Öyster Cult...
# Done.
# Searching for "Father And Son" by Yusuf / Cat Stevens...
# Done.
# Searching for "Knockin' On Heaven's Door" by Bob Dylan...
# Done.
# Searching for "Solsbury Hill" by Peter Gabriel...
# Done.
# Searching for "The Joker" by Steve Miller Band...
# Done.
# Searching for "Sweet Emotion" by Aerosmith...
# Done.
# Searching for "Bennie And The Jets - Remastered 2014" by Elton John...
# No results found for: 'Bennie And The Jets - Remastered 2014 Elton John'
# Searching for "Have You Ever Seen The Rain" by Creedence Clearwater Revival...
# Done.
# Searching for "Free Bird" by Lynyrd Skynyrd...
# Done.
# Searching for "You're So Vain" by Carly Simon...
# Searching for "Escape (The Pina Colada Song)" by Rupert Holmes...
# Done.
# Searching for "The Logical Song - Remastered 2010" by Supertramp...
# No results found for: 'The Logical Song - Remastered 2010 Supertramp'
# Searching for "Never Going Back Again - 2004 Remaster" by Fleetwood Mac...
# Done.
# Searching for "Take It Easy - 2013 Remaster" by Eagles...
# Done.
# Searching for "Don't Go Breaking My Heart" by Elton John...
# Searching for "Brandy (You're a Fine Girl)" by Looking Glass...
# Done.
# Searching for "Hooked On A Feeling" by Blue Swede...
# Done.
# Searching for "Simple Man" by Lynyrd Skynyrd...
# Done.
# Searching for "Layla" by Derek & The Dominos...
# Done.
# Searching for "She's Always a Woman" by Billy Joel...
# Done.
# Searching for "50 Ways to Leave Your Lover" by Paul Simon...
# Done.
# Searching for "Breakfast In America - 2010 Remastered" by Supertramp...
# No results found for: 'Breakfast In America - 2010 Remastered Supertramp'
# Searching for "Stairway to Heaven - Remaster" by Led Zeppelin...
# Done.
# Searching for "Another Brick in the Wall, Pt. 2" by Pink Floyd...
# Done.
# Searching for "Hotel California - 2013 Remaster" by Eagles...
# Done.
# Searching for "Miss You - Remastered" by The Rolling Stones...
# Done.
# Searching for "Heart Of Glass" by Blondie...
# Searching for "Psycho Killer - 2005 Remaster" by Talking Heads...
# Done.
# Searching for "Dust in the Wind" by Kansas...
# Done.
# Searching for "Move on Up - Single Edit" by Curtis Mayfield...
# Done.
# Searching for "Hurricane" by Bob Dylan...
# Done.
# Searching for "Don't Bring Me Down" by Electric Light Orchestra...
# Done.
# Searching for "Give A Little Bit" by Supertramp...
# Done.
# Searching for "Video Killed The Radio Star" by The Buggles...
# Done.
# Searching for "Come and Get Your Love - Single Version" by Redbone...
# Done.
# Searching for "Boys Don't Cry - Single Version" by The Cure...
# Done.
# Searching for "Easy" by Commodores...
# Searching for "Gimme! Gimme! Gimme! (A Man After Midnight)" by ABBA...
# Searching for "Baker Street" by Gerry Rafferty...
# Done.
# Searching for "Listen to the Music" by The Doobie Brothers...
# Done.
# Searching for "Into the Mystic - 2013 Remaster" by Van Morrison...
# Done.
# Searching for "Sweet Home Alabama" by Lynyrd Skynyrd...
# Searching for "Don't Stop Me Now - Remastered 2011" by Queen...
# Done.
# Searching for "More Than A Woman" by Bee Gees...
# Done.
# Searching for "Life on Mars? - 2015 Remaster" by David Bowie...
# Done.
# Searching for "December, 1963 (Oh What a Night!)" by Frankie Valli & The Four Seasons...
# Searching for "You Sexy Thing" by Hot Chocolate...
# Done.
# Searching for "Band On The Run - 2010 Remaster" by Paul McCartney...
# Done.
# Searching for "Ventura Highway" by America...
# Done.
# Searching for "Take Me Home, Country Roads" by John Denver...
# Searching for "Jolene" by Dolly Parton...
# Done.
# Searching for "September" by Earth, Wind & Fire...
# Done.
# Searching for "Perfect Day" by Lou Reed...
# Searching for "Somebody To Love - Remastered 2011" by Queen...
# Done.
# Searching for "Black Betty" by Ram Jam...
# Done.
# Searching for "Lola (2020 Stereo Remaster)" by The Kinks...
# Done.
# Searching for "Carry on Wayward Son" by Kansas...
# Searching for "The Boxer" by Simon & Garfunkel...
# Done.
# Searching for "American Girl" by Tom Petty and the Heartbreakers...
# Done.
# Searching for "Make Your Own Kind Of Music" by Cass Elliot...
# Done.
# Searching for "Born to Run" by Bruce Springsteen...
# Done.
# Searching for "Behind Blue Eyes" by The Who...
# Done.
# Searching for "Long Train Runnin'" by The Doobie Brothers...
# Done.
# Searching for "In the Summertime" by Mungo Jerry...
# Done.
# Searching for "Three Little Birds" by Bob Marley & The Wailers...
# Done.
# Searching for "One of These Nights - 2013 Remaster" by Eagles...
# Done.
# Searching for "The Boys Are Back In Town" by Thin Lizzy...
# Searching for "Dream On" by Aerosmith...
# Done.
# Searching for "Dirty Work" by Steely Dan...
# Done.
# Searching for "Our House" by Crosby, Stills, Nash & Young...
# Done.
# Searching for "Riders on the Storm" by The Doors...
# Done.
# Searching for "Crazy Little Thing Called Love - Remastered 2011" by Queen...
# Done.
# Searching for "Cocaine" by Eric Clapton...
# Done.
# Searching for "London Calling - Remastered" by The Clash...
# Done.
# Searching for "SOS" by ABBA...
# Done.
# Searching for "Jamming" by Bob Marley & The Wailers...
# Done.
# Searching for "Reelin' In The Years" by Steely Dan...
# Done.
# Searching for "Rebel Rebel - 2016 Remaster" by David Bowie...
# Done.
# Searching for "Because the Night" by Patti Smith...
# Searching for "Fire and Rain - 2019 Remaster" by James Taylor...
# Done.
# Searching for "I'm Not In Love" by 10cc...
# Done.
# Searching for "Immigrant Song - Remaster" by Led Zeppelin...
# No results found for: 'Immigrant Song - Remaster Led Zeppelin'
# Searching for "Is This Love" by Bob Marley & The Wailers...
# Done.
# Searching for "Bang a Gong (Get It On) - 2003 Remaster" by T. Rex...
# Done.
# Searching for "Imagine - Remastered 2010" by John Lennon...
# Done.
# Searching for "Oh! Sweet Nuthin' - 2015 Remaster" by The Velvet Underground...
# No results found for: 'Oh! Sweet Nuthin' - 2015 Remaster The Velvet Underground'
# Searching for "Sunny" by Boney M....
# Done.
# Searching for "Maggie May" by Rod Stewart...
# Done.
# Searching for "Dancing Queen" by ABBA...
# Searching for "Pink Moon" by Nick Drake...
# Done.
# Searching for "Summer Breeze" by Seals and Crofts...
# Done.
# Searching for "Love Grows (Where My Rosemary Goes)" by Edison Lighthouse...
# Done.
# Searching for "Da Ya Think I'm Sexy?" by Rod Stewart...
# Done.
# Searching for "Burning Love" by Elvis Presley...
# Done.
# Searching for "Do It Again" by Steely Dan...
# Done.
# Searching for "Lean on Me" by Bill Withers...
# Searching for "One Way or Another" by Blondie...
# Done.
# Searching for "Can't You See" by The Marshall Tucker Band...
# Done.
# Searching for "Cold as Ice" by Foreigner...
# Done.
# Searching for "Let It Be - Remastered 2009" by The Beatles...
# Done.
# Searching for "Livin' Thing" by Electric Light Orchestra...
# Searching for "Stumblin' In - 2017 Remaster" by Chris Norman...
# Done.
# Searching for "Signed, Sealed, Delivered (I'm Yours)" by Stevie Wonder...
# Done.
# Searching for "I Want You Back" by The Jackson 5...
# Done.
# Searching for "Surrender" by Cheap Trick...
# Done.
# Searching for "Wuthering Heights - 2018 Remaster" by Kate Bush...
# Done.
# Searching for "Kashmir - Remaster" by Led Zeppelin...
# No results found for: 'Kashmir - Remaster Led Zeppelin'
# Searching for "Angie - Remastered 2009" by The Rolling Stones...
# Done.
# Searching for "Low Rider" by War...
# Done.
# Searching for "Let's Stay Together" by Al Green...
# Done.
# Searching for "The Air That I Breathe - 2008 Remaster" by The Hollies...
# Done.
# Searching for "Cecilia" by Simon & Garfunkel...
# Done.
# Searching for "Stayin' Alive" by Bee Gees...
# Done.
# Searching for "Bohemian Rhapsody - Remastered 2011" by Queen...
# Done.
# Searching for "My Sharona" by The Knack...
# Done.
# Searching for "Barracuda" by Heart...
# Done.
# Searching for "Cat's in the Cradle" by Harry Chapin...
# Done.
# /var/folders/s6/ny1859490sj527r3gf8tnfrh0000gn/T/ipykernel_15250/64719398.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   song_df['lyrics'] = lyrics_vector

# %%
# songs_80s_with_lyrics = add_lyrics_to_df(songs_80s_filtered)
# Out:
# Searching for "Total Eclipse of the Heart" by Bonnie Tyler...
# Done.
# Searching for "Everywhere - 2017 Remaster" by Fleetwood Mac...
# Done.
# Searching for "Running Up That Hill (A Deal With God)" by Kate Bush...
# Done.
# Searching for "Heaven Is A Place On Earth - Promo 7" Edit" by Belinda Carlisle...
# No results found for: 'Heaven Is A Place On Earth - Promo 7" Edit Belinda Carlisle'
# Searching for "Smalltown Boy" by Bronski Beat...
# Done.
# Searching for "If I Could Turn Back Time" by Cher...
# Searching for "Take My Breath Away - Love Theme from "Top Gun"" by Berlin...
# Done.
# Searching for "Lay All Your Love On Me" by ABBA...
# Done.
# Searching for "Everybody Wants To Rule The World" by Tears For Fears...
# Done.
# Searching for "Enjoy the Silence" by Depeche Mode...
# Done.
# Searching for "Fast Car" by Tracy Chapman...
# Done.
# Searching for "With Or Without You" by U2...
# Done.
# Searching for "Little Lies - 2017 Remaster" by Fleetwood Mac...
# Done.
# Searching for "I'm On Fire" by Bruce Springsteen...
# Done.
# Searching for "Edge of Seventeen - 2016 Remaster" by Stevie Nicks...
# Done.
# Searching for "You Make My Dreams (Come True)" by Daryl Hall & John Oates...
# Done.
# Searching for "Don't Dream It's Over" by Crowded House...
# Searching for "Don't You (Forget About Me)" by Simple Minds...
# Searching for "Free Fallin'" by Tom Petty...
# Done.
# Searching for "I Still Haven't Found What I'm Looking For" by U2...
# Done.
# Searching for "Just like Heaven" by The Cure...
# Done.
# Searching for "Maneater" by Daryl Hall & John Oates...
# Done.
# Searching for "Dancing In the Dark" by Bruce Springsteen...
# Done.
# Searching for "Africa" by TOTO...
# Done.
# Searching for "Never Tear Us Apart" by INXS...
# Done.
# Searching for "Gypsy" by Fleetwood Mac...
# Done.
# Searching for "Sunday Bloody Sunday - Remastered 2008" by U2...
# Done.
# Searching for "You Can Call Me Al" by Paul Simon...
# Done.
# Searching for "Under Pressure - Remastered 2011" by Queen...
# Done.
# Searching for "Tainted Love" by Soft Cell...
# Searching for "Golden Brown" by The Stranglers...
# Done.
# Searching for "Bette Davis Eyes" by Kim Carnes...
# Done.
# Searching for "Your Love" by The Outfield...
# Searching for "In The Air Tonight - 2015 Remastered" by Phil Collins...
# Done.
# Searching for "The Boys Of Summer" by Don Henley...
# Done.
# Searching for "Money for Nothing" by Dire Straits...
# Done.
# Searching for "Don't Stop Believin'" by Journey...
# Done.
# Searching for "Love Will Tear Us Apart - 2020 Remaster" by Joy Division...
# Done.
# Searching for "Every Breath You Take" by The Police...
# Done.
# Searching for "Summer Of '69" by Bryan Adams...
# Done.
# Searching for "Down Under" by Men At Work...
# Done.
# Searching for "I'm Gonna Be (500 Miles)" by The Proclaimers...
# Done.
# Searching for "Need You Tonight" by INXS...
# Done.
# Searching for "We Didn't Start the Fire" by Billy Joel...
# Done.
# Searching for "Close to Me - 2006 Remaster" by The Cure...
# Done.
# Searching for "(I Just) Died In Your Arms" by Cutting Crew...
# Done.
# Searching for "Don't You Want Me" by The Human League...
# Done.
# Searching for "Where The Streets Have No Name - Remastered" by U2...
# No results found for: 'Where The Streets Have No Name - Remastered U2'
# Searching for "Could You Be Loved" by Bob Marley & The Wailers...
# Done.
# Searching for "Every Little Thing She Does Is Magic" by The Police...
# Done.
# Searching for "I Won't Back Down" by Tom Petty...
# Done.
# Searching for "Take on Me" by a-ha...
# Done.
# Searching for "Time After Time" by Cyndi Lauper...
# Searching for "Uptown Girl" by Billy Joel...
# Done.
# Searching for "How Soon Is Now? - 2011 Remaster" by The Smiths...
# Done.
# Searching for "She Drives Me Crazy" by Fine Young Cannibals...
# Done.
# Searching for "Forever Young" by Alphaville...
# Done.
# Searching for "Start Me Up - Remastered 2009" by The Rolling Stones...
# Done.
# Searching for "Walk of Life" by Dire Straits...
# Done.
# Searching for "Video Killed The Radio Star" by The Buggles...
# Searching for "Boys Don't Cry - Single Version" by The Cure...
# Done.
# Searching for "Another Day in Paradise - 2016 Remaster" by Phil Collins...
# Done.
# Searching for "There Is a Light That Never Goes Out - 2011 Remaster" by The Smiths...
# Done.
# Searching for "Easy Lover" by Philip Bailey...
# Done.
# Searching for "99 Luftballons" by Nena...
# Done.
# Searching for "Rock the Casbah - Remastered" by The Clash...
# Done.
# Searching for "Sweet Dreams (Are Made of This) - Remastered" by Eurythmics...
# No results found for: 'Sweet Dreams (Are Made of This) - Remastered Eurythmics'
# Searching for "Brothers in Arms" by Dire Straits...
# Done.
# Searching for "Talkin' Bout a Revolution" by Tracy Chapman...
# Done.
# Searching for "You Shook Me All Night Long" by AC/DC...
# Done.
# Searching for "Got My Mind Set on You" by George Harrison...
# Done.
# Searching for "Shout" by Tears For Fears...
# Done.
# Searching for "Purple Rain" by Prince...
# Done.
# Searching for "Should I Stay or Should I Go - Remastered" by The Clash...
# Done.
# Searching for "Run To You" by Bryan Adams...
# Done.
# Searching for "Sweet Child O' Mine" by Guns N' Roses...
# Done.
# Searching for "Jessie's Girl" by Rick Springfield...
# Done.
# Searching for "West End Girls - 2018 Remaster" by Pet Shop Boys...
# Done.
# Searching for "Rebel Yell - Remastered 1999" by Billy Idol...
# No results found for: 'Rebel Yell - Remastered 1999 Billy Idol'
# Searching for "Maniac - From "Flashdance"" by Michael Sembello...
# No results found for: 'Maniac - From "Flashdance" Michael Sembello'
# Searching for "All Night Long - Single Version" by Lionel Richie...
# Done.
# Searching for "Break My Stride" by Matthew Wilder...
# Done.
# Searching for "I'm Still Standing" by Elton John...
# Searching for "Only You" by Yazoo...
# Done.
# Searching for "Just Can't Get Enough" by Depeche Mode...
# Done.
# Searching for "Lovesong - 2010 Remaster" by The Cure...
# Done.
# Searching for "Call Me" by Blondie...
# Searching for "Beds Are Burning - Remastered" by Midnight Oil...
# Done.
# Searching for "Paradise City" by Guns N' Roses...
# Done.
# Searching for "More Than This" by Roxy Music...
# Done.
# Searching for "Faith - Remastered" by George Michael...
# Done.
# Searching for "It's My Life - 1997 Remaster" by Talk Talk...
# Done.
# Searching for "I Want to Know What Love Is - 1999 Remaster" by Foreigner...
# Done.
# Searching for "Livin' On A Prayer" by Bon Jovi...
# Done.
# Searching for "London Calling - Remastered" by The Clash...
# Done.
# Searching for "Englishman In New York" by Sting...
# Done.
# Searching for "Give It Up" by KC & The Sunshine Band...
# Done.
# Searching for "Walking On Sunshine" by Katrina & The Waves...
# Done.
# Searching for "Our House" by Madness...
# Done.
# Searching for "Don't Stand So Close To Me" by The Police...
# Done.
# Searching for "I Wanna Dance with Somebody (Who Loves Me)" by Whitney Houston...
# Done.
# Searching for "The Whole of the Moon - 2004 Remaster" by The Waterboys...
# Done.
# Searching for "The Way It Is" by Bruce Hornsby...
# Done.
# Searching for "Kokomo" by The Beach Boys...
# Done.
# Searching for "That's All - 2007 Remaster" by Genesis...
# Done.
# Searching for "Eyes Without A Face - Remastered 1999" by Billy Idol...
# Done.
# Searching for "Orinoco Flow - 2009 Remaster" by Enya...
# Done.
# Searching for "Kiss" by Prince...
# Done.
# Searching for "Hungry Like the Wolf - 2009 Remaster" by Duran Duran...
# Done.
# Searching for "Cold as Ice" by Foreigner...
# Done.
# Searching for "Hungry Eyes - From "Dirty Dancing" Soundtrack" by Eric Carmen...
# Done.
# Searching for "Rosanna" by TOTO...
# Done.
# Searching for "You Give Love A Bad Name" by Bon Jovi...
# Done.
# Searching for "Blue Monday '88 - 2015 Remaster" by New Order...
# Done.
# Searching for "Red Red Wine" by UB40...
# Done.
# Searching for "Relax" by Frankie Goes To Hollywood...
# Searching for "Pump Up The Jam" by Technotronic...
# Done.
# Searching for "Drive" by The Cars...
# Searching for "A Little Respect" by Erasure...
# Done.
# Searching for "Wake Me Up Before You Go-Go" by Wham!...
# Done.
# Searching for "You Can't Hurry Love - 2016 Remaster" by Phil Collins...
# Done.
# Searching for "Pour Some Sugar On Me" by Def Leppard...
# Done.
# Searching for "Owner of a Lonely Heart" by Yes...
# Done.
# Searching for "You're the Voice" by John Farnham...
# Searching for "Footloose - From "Footloose" Soundtrack" by Kenny Loggins...
# Done.
# Searching for "Islands in the Stream" by Dolly Parton...
# Done.
# Searching for "Kickstart My Heart" by Mötley Crüe...
# Done.
# Searching for "Any Way You Want It" by Journey...
# Done.
# Searching for "Jack & Diane" by John Mellencamp...
# Done.
# Searching for "Radio Ga Ga - Remastered 2011" by Queen...
# Done.
# Searching for "We Built This City" by Starship...
# Done.
# Searching for "Here Comes the Rain Again - Remastered Version" by Eurythmics...
# No results found for: 'Here Comes the Rain Again - Remastered Version Eurythmics'
# Searching for "Black Velvet" by Alannah Myles...
# Done.
# Searching for "I Think We're Alone Now" by Tiffany...
# Done.
# Searching for "You Got It" by Roy Orbison...
# Done.
# Searching for "Invisible Touch - 2007 Remaster" by Genesis...
# Done.
# Searching for "Jump - 2015 Remaster" by Van Halen...
# Done.
# Searching for "True - Single Edit" by Spandau Ballet...
# Done.
# Searching for "Another One Bites The Dust - Remastered 2011" by Queen...
# Done.
# Searching for "Born in the U.S.A." by Bruce Springsteen...
# Done.
# Searching for "Pride (In The Name Of Love) - Remastered 2009" by U2...
# No results found for: 'Pride (In The Name Of Love) - Remastered 2009 U2'
# Searching for "Heaven" by Bryan Adams...
# Done.
# Searching for "Wanted Dead Or Alive" by Bon Jovi...
# Done.
# Searching for "You Spin Me Round (Like a Record)" by Dead Or Alive...
# Searching for "Don't Worry Be Happy" by Bobby McFerrin...
# Done.
# Searching for "Sledgehammer - 2012 Remaster" by Peter Gabriel...
# No results found for: 'Sledgehammer - 2012 Remaster Peter Gabriel'
# Searching for "Poison" by Alice Cooper...
# Done.
# Searching for "The Look" by Roxette...
# Done.
# Searching for "The Winner Takes It All" by ABBA...
# Done.
# Searching for "Danger Zone - From "Top Gun" Original Soundtrack" by Kenny Loggins...
# No results found for: 'Danger Zone - From "Top Gun" Original Soundtrack Kenny Loggins'
# /var/folders/s6/ny1859490sj527r3gf8tnfrh0000gn/T/ipykernel_15250/64719398.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   song_df['lyrics'] = lyrics_vector

# %%
# songs_90s_with_lyrics = add_lyrics_to_df(songs_90s_filtered)
# Out:
# Searching for "No Scrubs" by TLC...
# Done.
# Searching for "Bitter Sweet Symphony - Remastered 2016" by The Verve...
# No results found for: 'Bitter Sweet Symphony - Remastered 2016 The Verve'
# Searching for "Torn" by Natalie Imbruglia...
# Done.
# Searching for "You Get What You Give" by New Radicals...
# Done.
# Searching for "Bitch" by Meredith Brooks...
# Done.
# Searching for "Save Tonight" by Eagle-Eye Cherry...
# Done.
# Searching for "All I Wanna Do" by Sheryl Crow...
# Searching for "She's so High" by Tal Bachman...
# Done.
# Searching for "Scar Tissue" by Red Hot Chili Peppers...
# Done.
# Searching for "Say My Name" by Destiny's Child...
# Done.
# Searching for "Iris" by The Goo Goo Dolls...
# Done.
# Searching for "Fade Into You" by Mazzy Star...
# Done.
# Searching for "Alright" by Supergrass...
# Done.
# Searching for "Closing Time" by Semisonic...
# Searching for "Wonderwall - Remastered" by Oasis...
# Done.
# Searching for "1979 - Remastered 2012" by The Smashing Pumpkins...
# Done.
# Searching for "Under the Bridge" by Red Hot Chili Peppers...
# Done.
# Searching for "Mr. Jones" by Counting Crows...
# Done.
# Searching for "Good Riddance (Time of Your Life)" by Green Day...
# Done.
# Searching for "Your Woman" by White Town...
# Done.
# Searching for "Teardrop" by Massive Attack...
# Done.
# Searching for "Champagne Supernova - Remastered" by Oasis...
# No results found for: 'Champagne Supernova - Remastered Oasis'
# Searching for "Praise You - Radio Edit" by Fatboy Slim...
# Done.
# Searching for "Otherside" by Red Hot Chili Peppers...
# Done.
# Searching for "There She Goes" by The La's...
# Done.
# Searching for "Fly Away" by Lenny Kravitz...
# Done.
# Searching for "Friday I'm in Love" by The Cure...
# Done.
# Searching for "Slide" by The Goo Goo Dolls...
# Done.
# Searching for "Learn to Fly" by Foo Fighters...
# Done.
# Searching for "Kiss Me" by Sixpence None The Richer...
# Searching for "Semi-Charmed Life" by Third Eye Blind...
# Done.
# Searching for "Two Princes" by Spin Doctors...
# Searching for "Californication" by Red Hot Chili Peppers...
# Searching for "Loser" by Beck...
# Done.
# Searching for "Song 2 - 2012 Remaster" by Blur...
# Done.
# Searching for "Lucky Man" by The Verve...
# Done.
# Searching for "Karma Police" by Radiohead...
# Done.
# Searching for "Wicked Game" by Chris Isaak...
# Done.
# Searching for "Don't Look Back In Anger - Remastered" by Oasis...
# Done.
# Searching for "Linger" by The Cranberries...
# Done.
# Searching for "Breakfast At Tiffany's" by Deep Blue Something...
# Done.
# Searching for "Losing My Religion" by R.E.M....
# Done.
# Searching for "Butterfly" by Crazy Town...
# Done.
# Searching for "High and Dry" by Radiohead...
# Done.
# Searching for "All The Small Things" by blink-182...
# Done.
# Searching for "No Rain" by Blind Melon...
# Searching for "How Bizarre" by OMC...
# Done.
# Searching for "My Hero" by Foo Fighters...
# Done.
# Searching for "Crash into Me" by Dave Matthews Band...
# Done.
# Searching for "Zombie" by The Cranberries...
# Done.
# Searching for "Enjoy the Silence" by Depeche Mode...
# Done.
# Searching for "Hallelujah" by Jeff Buckley...
# Done.
# Searching for "Tubthumping" by Chumbawamba...
# Done.
# Searching for "What's My Age Again?" by blink-182...
# Done.
# Searching for "Creep" by Radiohead...
# Searching for "Lightning Crashes" by Live...
# Done.
# Searching for "What's Up?" by 4 Non Blondes...
# Done.
# Searching for "Better Off Alone" by Alice Deejay...
# Done.
# Searching for "Ironic - 2015 Remaster" by Alanis Morissette...
# No results found for: 'Ironic - 2015 Remaster Alanis Morissette'
# Searching for "Santeria" by Sublime...
# Done.
# Searching for "One Headlight" by The Wallflowers...
# Done.
# Searching for "My Favourite Game" by The Cardigans...
# Done.
# Searching for "Disarm - 2011 Remaster" by The Smashing Pumpkins...
# Specified song does not contain lyrics. Rejecting.
# Searching for "I Try" by Macy Gray...
# Done.
# Searching for "Shiny Happy People" by R.E.M....
# Done.
# Searching for "Learning To Fly" by Tom Petty and the Heartbreakers...
# Done.
# Searching for "Around the World" by Daft Punk...
# Done.
# Searching for "Tonight, Tonight - Remastered 2012" by The Smashing Pumpkins...
# Done.
# Searching for "One" by U2...
# Done.
# Searching for "Self Esteem" by The Offspring...
# Done.
# Searching for "The Rhythm of the Night" by Corona...
# Done.
# Searching for "Layla - Acoustic Live" by Eric Clapton...
# Done.
# Searching for "Mmm Mmm Mmm Mmm" by Crash Test Dummies...
# Done.
# Searching for "If It Makes You Happy" by Sheryl Crow...
# Done.
# Searching for "Black Hole Sun" by Soundgarden...
# Searching for "Come As You Are" by Nirvana...
# Searching for "Children" by Robert Miles...
# Specified song does not contain lyrics. Rejecting.
# Searching for "Alive" by Pearl Jam...
# Done.
# Searching for "Don't Speak" by No Doubt...
# Done.
# Searching for "Believe" by Cher...
# Done.
# Searching for "The Bad Touch" by Bloodhound Gang...
# Done.
# Searching for "Push" by Matchbox Twenty...
# Done.
# Searching for "Sandstorm" by Darude...
# Done.
# Searching for "It Ain't Over 'Til It's Over" by Lenny Kravitz...
# Done.
# Searching for "A Girl Like You" by Edwyn Collins...
# Done.
# Searching for "Kiss from a Rose" by Seal...
# Searching for "Everybody Hurts" by R.E.M....
# Done.
# Searching for "Ordinary World" by Duran Duran...
# Done.
# Searching for "All Star" by Smash Mouth...
# Done.
# Searching for "Can I Kick It?" by A Tribe Called Quest...
# Done.
# Searching for "Angels" by Robbie Williams...
# Done.
# Searching for "3AM" by Matchbox Twenty...
# Done.
# Searching for "Here With Me" by Dido...
# Done.
# Searching for "Bullet With Butterfly Wings - Remastered 2012" by The Smashing Pumpkins...
# No results found for: 'Bullet With Butterfly Wings - Remastered 2012 The Smashing Pumpkins'
# Searching for "Freedom! '90 - Remastered" by George Michael...
# Done.
# Searching for "I Love You Always Forever" by Donna Lewis...
# Done.
# Searching for "The Kids Aren't Alright" by The Offspring...
# Done.
# Searching for "Just A Girl" by No Doubt...
# Searching for "Lithium" by Nirvana...
# Done.
# Searching for "When I Come Around" by Green Day...
# Done.
# Searching for "Insomnia - Radio Edit" by Faithless...
# Done.
# Searching for "Weather With You" by Crowded House...
# Done.
# Searching for "Thank You" by Dido...
# Done.
# Searching for "Narcotic - Radio Edit" by Liquido...
# Done.
# Searching for "Lovefool" by The Cardigans...
# Searching for "Common People - Full Length Version" by Pulp...
# Done.
# Searching for "Baby, I Love Your Way" by Big Mountain...
# Done.
# Searching for "Nothing Compares 2 U" by Sinéad O'Connor...
# Done.
# Searching for "Walkin' On The Sun" by Smash Mouth...
# Done.
# Searching for "Streets of Philadelphia - Single Edit" by Bruce Springsteen...
# Done.
# Searching for "Heart-Shaped Box" by Nirvana...
# Done.
# Searching for "What Is Love - 7" Mix" by Haddaway...
# Done.
# Searching for "Smooth (feat. Rob Thomas)" by Santana...
# Done.
# Searching for "Are You Gonna Go My Way" by Lenny Kravitz...
# Done.
# Searching for "Freed From Desire - prod. Molella, Phil Jay" by Gala...
# No results found for: 'Freed From Desire - prod. Molella, Phil Jay Gala'
# Searching for "Basket Case" by Green Day...
# Done.
# Searching for "Buddy Holly" by Weezer...
# Searching for "Nothing Else Matters (Remastered)" by Metallica...
# Done.
# Searching for "The Man Who Sold The World - Live" by Nirvana...
# Done.
# Searching for "Brimful Of Asha - Norman Cook Remix Single Version" by Cornershop...
# No results found for: 'Brimful Of Asha - Norman Cook Remix Single Version Cornershop'
# Searching for "Crazy" by Seal...
# Done.
# Searching for "'74-'75" by The Connells...
# Done.
# Searching for "Waterfalls" by TLC...
# Searching for "Thunderstruck" by AC/DC...
# Done.
# Searching for "Girls & Boys" by Blur...
# Done.
# Searching for "Tom's Diner - 7" Version" by DNA...
# Done.
# Searching for "Smells Like Teen Spirit" by Nirvana...
# Done.
# Searching for "Even Flow" by Pearl Jam...
# Searching for "November Rain" by Guns N' Roses...
# Done.
# Searching for "One Week" by Barenaked Ladies...
# Done.
# Searching for "No Diggity" by Blackstreet...
# Done.
# Searching for "Drinking in L.A." by Bran Van 3000...
# Done.
# Searching for "Blue (Da Ba Dee) - Gabry Ponte Ice Pop Radio" by Eiffel 65...
# No results found for: 'Blue (Da Ba Dee) - Gabry Ponte Ice Pop Radio Eiffel 65'
# Searching for "All That She Wants" by Ace of Base...
# Done.
# Searching for "Ode To My Family" by The Cranberries...
# Done.
# Searching for "Knockin' On Heaven's Door" by Guns N' Roses...
# Done.
# Searching for "Miami" by Will Smith...
# Done.
# Searching for "Give It Away" by Red Hot Chili Peppers...
# Done.
# Searching for "Runaway Train (2022 Remaster)" by Soul Asylum...
# Done.
# Searching for "The Bomb! (These Sound Fall into My Mind) - Radio Edit" by The Bucketheads...
# No results found for: 'The Bomb! (These Sound Fall into My Mind) - Radio Edit The Bucketheads'
# Searching for "You Oughta Know - 2015 Remaster" by Alanis Morissette...
# Done.
# Searching for "Pretty Fly (For A White Guy)" by The Offspring...
# Done.
# Searching for "Return of the Mack" by Mark Morrison...
# Done.
# Searching for "Enter Sandman (Remastered)" by Metallica...
# Done.
# Searching for "Only Wanna Be With You" by Hootie & The Blowfish...
# Done.
# Searching for "To Be With You - 2010 Remastered Version" by Mr. Big...
# Done.
# Searching for "Life Is A Highway" by Tom Cochrane...
# Done.
# Searching for "Push The Feeling On - Mk Dub Revisited Edit" by Nightcrawlers...
# Done.
# Searching for "Groove Is in the Heart" by Deee-Lite...
# Done.
# Searching for "I Don't Want to Miss a Thing - From "Armageddon" Soundtrack" by Aerosmith...
# No results found for: 'I Don't Want to Miss a Thing - From "Armageddon" Soundtrack Aerosmith'
# /var/folders/s6/ny1859490sj527r3gf8tnfrh0000gn/T/ipykernel_15250/64719398.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   song_df['lyrics'] = lyrics_vector

# %%
# songs_2000s_with_lyrics = add_lyrics_to_df(songs_2000s_filtered)
# Out:
# Searching for "Since U Been Gone" by Kelly Clarkson...
# Done.
# Searching for "Yeah! (feat. Lil Jon & Ludacris)" by USHER...
# Done.
# Searching for "Murder On The Dancefloor" by Sophie Ellis-Bextor...
# Searching for "Sweet Disposition" by The Temper Trap...
# Done.
# Searching for "Crazy In Love (feat. Jay-Z)" by Beyoncé...
# Done.
# Searching for "Walking On A Dream" by Empire Of The Sun...
# Done.
# Searching for "Kids" by MGMT...
# Done.
# Searching for "Young Folks" by Peter Bjorn and John...
# Done.
# Searching for "Naive" by The Kooks...
# Done.
# Searching for "Apologize" by Timbaland...
# Done.
# Searching for "Home (2019 Remaster)" by Edward Sharpe & The Magnetic Zeros...
# No results found for: 'Home (2019 Remaster) Edward Sharpe & The Magnetic Zeros'
# Searching for "You've Got The Love" by Florence + The Machine...
# Done.
# Searching for "Intro" by The xx...
# Specified song does not contain lyrics. Rejecting.
# Searching for "Use Somebody" by Kings of Leon...
# Done.
# Searching for "Mr. Brightside" by The Killers...
# Done.
# Searching for "Little Lion Man" by Mumford & Sons...
# Done.
# Searching for "Electric Feel" by MGMT...
# Done.
# Searching for "The Funeral" by Band of Horses...
# Done.
# Searching for "A-Punk" by Vampire Weekend...
# Done.
# Searching for "Dog Days Are Over" by Florence + The Machine...
# Done.
# Searching for "Island In The Sun" by Weezer...
# Done.
# Searching for "Heartbeats" by José González...
# Done.
# Searching for "Sex on Fire" by Kings of Leon...
# Done.
# Searching for "Clocks" by Coldplay...
# Done.
# Searching for "Human" by The Killers...
# Done.
# Searching for "Take Me Out" by Franz Ferdinand...
# Done.
# Searching for "Dancing in the Moonlight" by Toploader...
# Done.
# Searching for "Pumped Up Kicks" by Foster The People...
# Done.
# Searching for "Beautiful Day" by U2...
# Done.
# Searching for "Chasing Cars" by Snow Patrol...
# Done.
# Searching for "Last Nite" by The Strokes...
# Done.
# Searching for "Banquet" by Bloc Party...
# Done.
# Searching for "Porcelain" by Moby...
# Done.
# Searching for "Snow (Hey Oh)" by Red Hot Chili Peppers...
# Done.
# Searching for "When You Were Young" by The Killers...
# Done.
# Searching for "Crazy" by Gnarls Barkley...
# Done.
# Searching for "The Middle" by Jimmy Eat World...
# Searching for "How to Save a Life" by The Fray...
# Searching for "Call on Me - Radio Mix" by Eric Prydz...
# Done.
# Searching for "Cosmic Love" by Florence + The Machine...
# Done.
# Searching for "Cooler Than Me - Single Mix" by Mike Posner...
# Done.
# Searching for "Dancing On My Own - Radio Edit" by Robyn...
# Done.
# Searching for "Are You Gonna Be My Girl" by Jet...
# Done.
# Searching for "Can't Stop" by Red Hot Chili Peppers...
# Done.
# Searching for "Bulletproof" by La Roux...
# Done.
# Searching for "Animal" by Miike Snow...
# Done.
# Searching for "Better Together" by Jack Johnson...
# Done.
# Searching for "Starlight" by Muse...
# Done.
# Searching for "Heads Will Roll" by Yeah Yeah Yeahs...
# Done.
# Searching for "Yellow" by Coldplay...
# Done.
# Searching for "Sing" by Travis...
# Done.
# Searching for "I Miss You" by blink-182...
# Done.
# Searching for "Lady - Hear Me Tonight" by Modjo...
# Done.
# Searching for "Feel Good Inc." by Gorillaz...
# Searching for "Hey There Delilah" by Plain White T's...
# Done.
# Searching for "Meet Me Halfway" by Black Eyed Peas...
# Done.
# Searching for "Ruby" by Kaiser Chiefs...
# Done.
# Searching for "You Found Me" by The Fray...
# Done.
# Searching for "Teenage Dirtbag" by Wheatus...
# Done.
# Searching for "The Scientist" by Coldplay...
# Done.
# Searching for "Dani California" by Red Hot Chili Peppers...
# Done.
# Searching for "Unwritten" by Natasha Bedingfield...
# Done.
# Searching for "Waiting On the World to Change" by John Mayer...
# Done.
# Searching for "The Sweet Escape" by Gwen Stefani...
# Done.
# Searching for "Somewhere Only We Know" by Keane...
# Done.
# Searching for "Best of You" by Foo Fighters...
# Done.
# Searching for "Seven Nation Army" by The White Stripes...
# Done.
# Searching for "I Believe in a Thing Called Love" by The Darkness...
# Searching for "Californication" by Red Hot Chili Peppers...
# Done.
# Searching for "Fix You" by Coldplay...
# Done.
# Searching for "Superstar (feat. Matthew Santos)" by Lupe Fiasco...
# Done.
# Searching for "Hey Ya!" by Outkast...
# Done.
# Searching for "Gives You Hell" by The All-American Rejects...
# Done.
# Searching for "The Pretender" by Foo Fighters...
# Done.
# Searching for "Uprising" by Muse...
# Done.
# Searching for "No One Knows" by Queens of the Stone Age...
# Done.
# Searching for "White Flag" by Dido...
# Done.
# Searching for "I Don't Want to Be" by Gavin DeGraw...
# Done.
# Searching for "Viva La Vida" by Coldplay...
# Done.
# Searching for "California - Tchad Blake Mix" by Phantom Planet...
# Done.
# Searching for "When The Sun Goes Down" by Arctic Monkeys...
# Done.
# Searching for "Butterfly" by Crazy Town...
# Done.
# Searching for "The Man Who Can't Be Moved" by The Script...
# Done.
# Searching for "Pjanoo - Radio Edit" by Eric Prydz...
# Done.
# Searching for "By the Way" by Red Hot Chili Peppers...
# Done.
# Searching for "She Will Be Loved - Radio Mix" by Maroon 5...
# Done.
# Searching for "Roses" by Outkast...
# Done.
# Searching for "D.A.N.C.E" by Justice...
# Done.
# Searching for "Infinity - Magic Mitch Club Mix" by Guru Josh Project...
# Done.
# Searching for "Everybody's Changing" by Keane...
# Done.
# Searching for "Fireflies" by Owl City...
# Done.
# Searching for "Hey, Soul Sister" by Train...
# Done.
# Searching for "When Love Takes Over (feat. Kelly Rowland)" by David Guetta...
# Done.
# Searching for "Kryptonite" by 3 Doors Down...
# Searching for "This Is The Life" by Amy Macdonald...
# Done.
# Searching for "American Boy" by Estelle...
# Done.
# Searching for "Grace Kelly" by MIKA...
# Done.
# Searching for "Free Fallin' - Live at the Nokia Theatre, Los Angeles, CA - December 2007" by John Mayer...
# No results found for: 'Free Fallin' - Live at the Nokia Theatre, Los Angeles, CA - December 2007 John Mayer'
# Searching for "New Shoes" by Paolo Nutini...
# Done.
# Searching for "Tears Dry On Their Own" by Amy Winehouse...
# Done.
# Searching for "Shake It" by Metro Station...
# Done.
# Searching for "This Love" by Maroon 5...
# Done.
# Searching for "Golden Skans" by Klaxons...
# Done.
# Searching for "How You Remind Me" by Nickelback...
# Searching for "Valerie - Live At BBC Radio 1 Live Lounge, London / 2007" by Amy Winehouse...
# Done.
# Searching for "Last Request" by Paolo Nutini...
# Done.
# Searching for "I'm Like A Bird" by Nelly Furtado...
# Done.
# Searching for "Thnks fr th Mmrs" by Fall Out Boy...
# Done.
# Searching for "In Too Deep" by Sum 41...
# Done.
# Searching for "Can't Get You out of My Head" by Kylie Minogue...
# Done.
# Searching for "Hung Up" by Madonna...
# Done.
# Searching for "I Write Sins Not Tragedies" by Panic! At The Disco...
# Done.
# Searching for "Move Your Feet" by Junior Senior...
# Done.
# Searching for "1234" by Feist...
# Done.
# Searching for "Love Song" by Sara Bareilles...
# Done.
# Searching for "Ms. Jackson" by Outkast...
# Done.
# Searching for "Wherever You Will Go" by The Calling...
# Done.
# Searching for "Say It Right" by Nelly Furtado...
# Done.
# Searching for "Sugar, We're Goin Down" by Fall Out Boy...
# Done.
# Searching for "All My Life" by Foo Fighters...
# Done.
# Searching for "The Way I Are" by Timbaland...
# Done.
# Searching for "Behind Blue Eyes" by Limp Bizkit...
# Done.
# Searching for "Sandstorm" by Darude...
# Done.
# Searching for "I Gotta Feeling" by Black Eyed Peas...
# Done.
# Searching for "Boulevard of Broken Dreams" by Green Day...
# Searching for "Savior" by Rise Against...
# Done.
# Searching for "Promiscuous" by Nelly Furtado...
# Searching for "Bonkers" by Dizzee Rascal...
# Done.
# Searching for "Broken Strings" by James Morrison...
# Done.
# Searching for "Put Your Records On" by Corinne Bailey Rae...
# Done.
# Searching for "Clint Eastwood" by Gorillaz...
# Done.
# Searching for "Day 'N' Nite (nightmare)" by Kid Cudi...
# Done.
# Searching for "Chasing Pavements" by Adele...
# Done.
# Searching for "Maneater" by Nelly Furtado...
# Searching for "Empire State Of Mind" by JAY-Z...
# Done.
# Searching for "Smile" by Lily Allen...
# Done.
# Searching for "Pure Shores" by All Saints...
# Done.
# Searching for "Back To Black" by Amy Winehouse...
# Done.
# Searching for "Stronger" by Kanye West...
# Searching for "Mercy" by Duffy...
# Done.
# Searching for "Your Body Is a Wonderland" by John Mayer...
# Done.
# Searching for "Rockstar - 2020 Remaster" by Nickelback...
# No results found for: 'Rockstar - 2020 Remaster Nickelback'
# Searching for "Numb / Encore" by JAY-Z...
# Done.
# Searching for "Feel" by Robbie Williams...
# Done.
# Searching for "Dirty Little Secret" by The All-American Rejects...
# Done.
# Searching for "Where Is The Love?" by Black Eyed Peas...
# Done.
# Searching for "Rehab" by Amy Winehouse...
# Searching for "Fat Lip" by Sum 41...
# Done.
# Searching for "Harder, Better, Faster, Stronger" by Daft Punk...
# Done.
# Searching for "I Don't Feel Like Dancin'" by Scissor Sisters...
# Done.
# /var/folders/s6/ny1859490sj527r3gf8tnfrh0000gn/T/ipykernel_15250/64719398.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   song_df['lyrics'] = lyrics_vector

# %%
# songs_2010s_with_lyrics = add_lyrics_to_df(songs_2010s_filtered)
# Out:
# Searching for "bad guy" by Billie Eilish...
# Done.
# Searching for "Midnight City" by M83...
# Done.
# Searching for "Stolen Dance" by Milky Chance...
# Done.
# Searching for "Ophelia" by The Lumineers...
# Done.
# Searching for "when the party's over" by Billie Eilish...
# Done.
# Searching for "Little Talks" by Of Monsters and Men...
# Done.
# Searching for "The Less I Know The Better" by Tame Impala...
# Done.
# Searching for "Feel So Close - Radio Edit" by Calvin Harris...
# Done.
# Searching for "Team" by Lorde...
# Done.
# Searching for "I Will Wait" by Mumford & Sons...
# Done.
# Searching for "Riptide" by Vance Joy...
# Done.
# Searching for "3 Nights" by Dominic Fike...
# Done.
# Searching for "Budapest" by George Ezra...
# Done.
# Searching for "Ho Hey" by The Lumineers...
# Done.
# Searching for "Roses" by The Chainsmokers...
# Done.
# Searching for "I Got U" by Duke Dumont...
# Done.
# Searching for "Electric Love" by BØRNS...
# Done.
# Searching for "Waves - Robin Schulz Radio Edit" by Mr. Probz...
# Done.
# Searching for "Nevermind" by Dennis Lloyd...
# Done.
# Searching for "Never Be Like You (feat. Kai)" by Flume...
# Done.
# Searching for "Prayer in C - Robin Schulz Radio Edit" by Lilly Wood and The Prick...
# Done.
# Searching for "Stole the Show" by Kygo...
# Done.
# Searching for "Latch" by Disclosure...
# Done.
# Searching for "Sugar (feat. Francesco Yates)" by Robin Schulz...
# Done.
# Searching for "Don't You Worry Child - Radio Edit" by Swedish House Mafia...
# Done.
# Searching for "Renegades" by X Ambassadors...
# Done.
# Searching for "Summertime Sadness (Lana Del Rey Vs. Cedric Gervais) - Cedric Gervais Remix" by Lana Del Rey...
# No results found for: 'Summertime Sadness (Lana Del Rey Vs. Cedric Gervais) - Cedric Gervais Remix Lana Del Rey'
# Searching for "Hold Back The River" by James Bay...
# Done.
# Searching for "Firestone" by Kygo...
# Done.
# Searching for "Pumped Up Kicks" by Foster The People...
# Done.
# Searching for "Lost" by Frank Ocean...
# Searching for "This Girl (Kungs Vs. Cookin' On 3 Burners)" by Kungs...
# Done.
# Searching for "Fast Car" by Jonas Blue...
# Done.
# Searching for "Somebody Else" by The 1975...
# Done.
# Searching for "Feel It Still" by Portugal. The Man...
# Done.
# Searching for "I Took A Pill In Ibiza - Seeb Remix" by Mike Posner...
# Done.
# Searching for "Safe And Sound" by Capital Cities...
# Done.
# Searching for "Summer" by Calvin Harris...
# Done.
# Searching for "Sail" by AWOLNATION...
# Done.
# Searching for "Paradise" by Coldplay...
# Done.
# Searching for "Are You With Me - Radio Edit" by Lost Frequencies...
# Done.
# Searching for "We Are Young (feat. Janelle Monáe)" by fun....
# Searching for "Blame (feat. John Newman)" by Calvin Harris...
# Done.
# Searching for "Somebody That I Used To Know" by Gotye...
# Done.
# Searching for "Body" by Loud Luxury...
# Done.
# Searching for "Feel the Love (feat. John Newman)" by Rudimental...
# Done.
# Searching for "Levels - Radio Edit" by Avicii...
# Done.
# Searching for "Pompeii" by Bastille...
# Done.
# Searching for "Cool Kids" by Echosmith...
# Done.
# Searching for "A Sky Full of Stars" by Coldplay...
# Done.
# Searching for "King" by Olly Alexander (Years & Years)...
# Done.
# Searching for "Memories (feat. Kid Cudi)" by David Guetta...
# Done.
# Searching for "Love Me Again" by John Newman...
# Done.
# Searching for "Habits (Stay High)" by Tove Lo...
# Done.
# Searching for "I Love It (feat. Charli XCX)" by Icona Pop...
# Done.
# Searching for "Hideaway" by Kiesza...
# Done.
# Searching for "Sweater Weather" by The Neighbourhood...
# Searching for "Take Me to Church" by Hozier...
# Searching for "8TEEN" by Khalid...
# Done.
# Searching for "Heroes (we could be)" by Alesso...
# Done.
# Searching for "All My Friends (feat. Tinashe & Chance the Rapper)" by Snakehips...
# Done.
# Searching for "Some Nights" by fun....
# Done.
# Searching for "Let It Go" by James Bay...
# Searching for "Do I Wanna Know?" by Arctic Monkeys...
# Done.
# Searching for "I Could Be The One (Avicii Vs. Nicky Romero) - Radio Edit" by Avicii...
# Done.
# Searching for "Malibu" by Miley Cyrus...
# Done.
# Searching for "More Than You Know" by Axwell /\ Ingrosso...
# Done.
# Searching for "Remind Me to Forget" by Kygo...
# Done.
# Searching for "Ain't Nobody (Loves Me Better) (feat. Jasmine Thompson)" by Felix Jaehn...
# Done.
# Searching for "Outside (feat. Ellie Goulding)" by Calvin Harris...
# Done.
# Searching for "Lean On" by Major Lazer...
# Done.
# Searching for "Royals" by Lorde...
# Done.
# Searching for "Sign of the Times" by Harry Styles...
# Done.
# Searching for "Strong" by London Grammar...
# Done.
# Searching for "Wild Ones (feat. Sia)" by Flo Rida...
# Done.
# Searching for "Wasted" by Tiësto...
# Done.
# Searching for "All I Want" by Kodaline...
# Done.
# Searching for "Without You (feat. Sandro Cavazza)" by Avicii...
# Done.
# Searching for "Slide (feat. Frank Ocean & Migos)" by Calvin Harris...
# Done.
# Searching for "Dark Necessities" by Red Hot Chili Peppers...
# Done.
# Searching for "Stay" by Rihanna...
# Done.
# Searching for "Chocolate" by The 1975...
# Done.
# Searching for "Drive By" by Train...
# Done.
# Searching for "Middle" by DJ Snake...
# Done.
# Searching for "Unsteady" by X Ambassadors...
# Done.
# Searching for "Paris" by The Chainsmokers...
# Done.
# Searching for "Ride" by Twenty One Pilots...
# Done.
# Searching for "Hey Brother" by Avicii...
# Done.
# Searching for "It Ain’t Me (with Selena Gomez)" by Kygo...
# Done.
# Searching for "FourFiveSeconds" by Rihanna...
# Done.
# Searching for "Call on Me - Ryan Riback Remix" by Starley...
# Done.
# Searching for "The A Team" by Ed Sheeran...
# Done.
# Searching for "Wait a Minute!" by WILLOW...
# Done.
# Searching for "1950" by King Princess...
# Done.
# Searching for "Wake Me Up" by Avicii...
# Done.
# Searching for "Final Song" by MØ...
# Done.
# Searching for "Titanium (feat. Sia)" by David Guetta...
# Done.
# Searching for "Higher Love" by Kygo...
# Done.
# Searching for "Redbone" by Childish Gambino...
# Done.
# Searching for "Silence" by Marshmello...
# Done.
# Searching for "Rather Be (feat. Jess Glynne)" by Clean Bandit...
# Done.
# Searching for "Easy Love" by Sigala...
# Done.
# Searching for "Why'd You Only Call Me When You're High?" by Arctic Monkeys...
# Done.
# Searching for "Power Over Me" by Dermot Kennedy...
# Done.
# Searching for "Save The World" by Swedish House Mafia...
# Done.
# Searching for "Dancing On My Own" by Calum Scott...
# Done.
# Searching for "Lush Life" by Zara Larsson...
# Searching for "Solo Dance" by Martin Jensen...
# Done.
# Searching for "Jackie Chan" by Tiësto...
# Done.
# Searching for "Something Just Like This" by The Chainsmokers...
# Done.
# Searching for "Waiting All Night (feat. Ella Eyre)" by Rudimental...
# Done.
# Searching for "Fireflies" by Owl City...
# Done.
# Searching for "Shotgun" by George Ezra...
# Done.
# Searching for "Young And Beautiful" by Lana Del Rey...
# Done.
# Searching for "Circles" by Post Malone...
# Done.
# Searching for "We Found Love" by Rihanna...
# Done.
# Searching for "Shut Up and Dance" by WALK THE MOON...
# Done.
# Searching for "All The Stars (with SZA)" by Kendrick Lamar...
# Done.
# Searching for "Good Feeling" by Flo Rida...
# Done.
# Searching for "I Feel It Coming" by The Weeknd...
# Searching for "In My Mind" by Dynoro...
# Done.
# Searching for "You Know You Like It" by DJ Snake...
# Done.
# Searching for "Sweet Lovin' - Radio Edit" by Sigala...
# Done.
# Searching for "Can't Hold Us (feat. Ray Dalton)" by Macklemore & Ryan Lewis...
# Done.
# Searching for "Time of Our Lives" by Pitbull...
# Done.
# Searching for "Elastic Heart" by Sia...
# Done.
# Searching for "Apocalypse" by Cigarettes After Sex...
# Done.
# Searching for "Be the One" by Dua Lipa...
# Done.
# Searching for "Gold" by Kiiara...
# Done.
# Searching for "Can't Feel My Face" by The Weeknd...
# Searching for "Leave a Light On" by Tom Walker...
# Done.
# Searching for "Scared to Be Lonely" by Martin Garrix...
# Done.
# Searching for "Am I Wrong" by Nico & Vinz...
# Searching for "Intoxicated - Radio Edit" by Martin Solveig...
# Done.
# Searching for "Light It Up (Remix)" by Major Lazer...
# Done.
# Searching for "Young Dumb & Broke" by Khalid...
# Done.
# Searching for "Without You (feat. Usher)" by David Guetta...
# Done.
# Searching for "Hide Away" by Daya...
# Done.
# Searching for "Where Are Ü Now (with Justin Bieber)" by Jack Ü...
# Done.
# Searching for "Wherever I Go" by OneRepublic...
# Done.
# Searching for "Get Lucky (Radio Edit) [feat. Pharrell Williams and Nile Rodgers]" by Daft Punk...
# Done.
# Searching for "Five More Hours" by Deorro...
# Done.
# Searching for "This Town" by Niall Horan...
# Done.
# Searching for "Castle on the Hill" by Ed Sheeran...
# Done.
# Searching for "Hold My Hand" by Jess Glynne...
# Done.
# Searching for "Stressed Out" by Twenty One Pilots...
# Done.
# Searching for "Never Forget You" by Zara Larsson...
# Done.
# Searching for "Counting Stars" by OneRepublic...
# Done.
# Searching for "Ride It" by Regard...
# Done.
# Searching for "Pink + White" by Frank Ocean...
# Done.
# /var/folders/s6/ny1859490sj527r3gf8tnfrh0000gn/T/ipykernel_15250/64719398.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   song_df['lyrics'] = lyrics_vector

# %%
# songs_2020s_with_lyrics = add_lyrics_to_df(songs_2020s_filtered)
# Out:
# Searching for "Escapism." by RAYE...
# Done.
# Searching for "Stick Season" by Noah Kahan...
# Done.
# Searching for "Seventeen Going Under" by Sam Fender...
# Done.
# Searching for "Borderline" by Tame Impala...
# Done.
# Searching for "Something in the Orange" by Zach Bryan...
# Done.
# Searching for "Afraid To Feel" by LF SYSTEM...
# Done.
# Searching for "Where Are You Now" by Lost Frequencies...
# Done.
# Searching for "Meet Me At Our Spot" by THE ANXIETY...
# Done.
# Searching for "Heat Waves" by Glass Animals...
# Done.
# Searching for "Strangers" by Kenya Grace...
# Done.
# Searching for "Love Tonight (David Guetta Remix Edit)" by Shouse...
# Done.
# Searching for "Beautiful Things" by Benson Boone...
# Done.
# Searching for "Miracle (with Ellie Goulding)" by Calvin Harris...
# Done.
# Searching for "(It Goes Like) Nanana - Edit" by Peggy Gou...
# Done.
# Searching for "I Ain't Worried" by OneRepublic...
# Done.
# Searching for "Ferrari" by James Hype...
# Done.
# Searching for "Lose Control" by Teddy Swims...
# Done.
# Searching for "ceilings" by Lizzy McAlpine...
# Done.
# Searching for "Remember (with David Guetta)" by Becky Hill...
# Done.
# Searching for "Cold Heart - PNAU Remix" by Elton John...
# Searching for "Daylight" by David Kushner...
# Done.
# Searching for "As It Was" by Harry Styles...
# Done.
# Searching for "Head & Heart (feat. MNEK)" by Joel Corry...
# Done.
# Searching for "Heaven" by Niall Horan...
# Done.
# Searching for "Bad Habit" by Steve Lacy...
# Done.
# Searching for "The Motto" by Tiësto...
# Done.
# Searching for "Rasputin" by Majestic...
# Done.
# Searching for "vampire" by Olivia Rodrigo...
# Done.
# Searching for "Lovin On Me" by Jack Harlow...
# Done.
# Searching for "Little Bit of Love" by Tom Grennan...
# Done.
# Searching for "Late Night Talking" by Harry Styles...
# Done.
# Searching for "Fast Car" by Luke Combs...
# Done.
# Searching for "Supalonely" by BENEE...
# Done.
# Searching for "drivers license" by Olivia Rodrigo...
# Searching for "Karma" by Taylor Swift...
# Done.
# Searching for "Blinding Lights" by The Weeknd...
# Searching for "Run" by OneRepublic...
# Done.
# Searching for "SNAP" by Rosa Linn...
# Done.
# Searching for "I'm Good (Blue)" by David Guetta...
# Done.
# Searching for "good 4 u" by Olivia Rodrigo...
# Searching for "21 Reasons (feat. Ella Henderson)" by Nathan Dawe...
# Done.
# Searching for "Forget Me" by Lewis Capaldi...
# Done.
# Searching for "Sunroof" by Nicky Youre...
# Done.
# Searching for "Lil Boo Thang" by Paul Russell...
# Done.
# Searching for "greedy" by Tate McRae...
# Done.
# Searching for "Oh My God" by Adele...
# Done.
# Searching for "august" by Taylor Swift...
# Done.
# Searching for "Good Days" by SZA...
# Done.
# Searching for "OUT OUT (feat. Charli XCX & Saweetie)" by Joel Corry...
# Done.
# Searching for "deja vu" by Olivia Rodrigo...
# Done.
# Searching for "edamame" by bbno$...
# Done.
# Searching for "you broke me first" by Tate McRae...
# Done.
# Searching for "What Was I Made For? [From The Motion Picture "Barbie"]" by Billie Eilish...
# Done.
# Searching for "Until I Found You" by Stephen Sanchez...
# Done.
# Searching for "Here With Me" by d4vd...
# Done.
# Searching for "Bad Habits" by Ed Sheeran...
# Done.
# Searching for "Anti-Hero" by Taylor Swift...
# Done.
# Searching for "Goosebumps - Remix" by Travis Scott...
# Done.
# Searching for "we can't be friends (wait for your love)" by Ariana Grande...
# Done.
# Searching for "Green Green Grass" by George Ezra...
# Done.
# Searching for "Save Your Tears (with Ariana Grande) (Remix)" by The Weeknd...
# Done.
# Searching for "Dance The Night - From Barbie The Album" by Dua Lipa...
# Done.
# Searching for "First Class" by Jack Harlow...
# Done.
# Searching for "Happier Than Ever" by Billie Eilish...
# Done.
# Searching for "cardigan" by Taylor Swift...
# Searching for "Feather" by Sabrina Carpenter...
# Done.
# Searching for "death bed (coffee for your head)" by Powfu...
# Done.
# Searching for "hot girl bummer" by blackbear...
# Done.
# Searching for "In The Stars" by Benson Boone...
# Done.
# Searching for "Wonder" by Shawn Mendes...
# Done.
# Searching for "Shivers" by Ed Sheeran...
# Done.
# Searching for "Ghost" by Justin Bieber...
# Done.
# Searching for "Glimpse of Us" by Joji...
# Done.
# Searching for "Heather" by Conan Gray...
# Done.
# Searching for "My Love Mine All Mine" by Mitski...
# Done.
# Searching for "Romantic Homicide" by d4vd...
# Done.
# Searching for "Calm Down (with Selena Gomez)" by Rema...
# Done.
# Searching for "About Damn Time" by Lizzo...
# Done.
# Searching for "Levitating (feat. DaBaby)" by Dua Lipa...
# Done.
# Searching for "Eyes Closed" by Ed Sheeran...
# Done.
# Searching for "Angels Like You" by Miley Cyrus...
# Done.
# Searching for "Big Energy" by Latto...
# Done.
# Searching for "If We Ever Broke Up" by Mae Stephens...
# Done.
# Searching for "CUFF IT" by Beyoncé...
# Done.
# Searching for "STAY (with Justin Bieber)" by The Kid LAROI...
# Done.
# Searching for "Mood (feat. iann dior)" by 24kGoldn...
# Done.
# Searching for "abcdefu" by GAYLE...
# Done.
# Searching for "Flowers" by Miley Cyrus...
# Searching for "Life Goes On" by Oliver Tree...
# Done.
# Searching for "Kiss Me More (feat. SZA)" by Doja Cat...
# Done.
# Searching for "Bam Bam (feat. Ed Sheeran)" by Camila Cabello...
# Done.
# Searching for "Pepas" by Farruko...
# Done.
# Searching for "Control" by Zoe Wees...
# Done.
# Searching for "Easy On Me" by Adele...
# Done.
# Searching for "Boyfriend" by Dove Cameron...
# Done.
# Searching for "Rush" by Ayra Starr...
# Done.
# Searching for "Nonsense" by Sabrina Carpenter...
# Done.
# Searching for "I'm Just Ken (From Barbie The Album)" by Ryan Gosling...
# Done.
# Searching for "I WANNA BE YOUR SLAVE" by Måneskin...
# Done.
# Searching for "Paint The Town Red" by Doja Cat...
# Done.
# Searching for "3:15 (Breathe)" by Russ...
# Done.
# Searching for "Water" by Tyla...
# Done.
# Searching for "Pain" by PinkPantheress...
# Done.
# Searching for "Kill Bill" by SZA...
# Done.
# Searching for "My Universe" by Coldplay...
# Searching for "the perfect pair" by beabadoobee...
# Done.
# Searching for "Die For You" by Joji...
# Done.
# Searching for "Vegas (From the Original Motion Picture Soundtrack ELVIS)" by Doja Cat...
# Done.
# Searching for "2055" by Sleepy Hallow...
# Done.
# Searching for "Creepin' (with The Weeknd & 21 Savage)" by Metro Boomin...
# Done.
# Searching for "From The Start" by Laufey...
# Done.
# Searching for "Unholy (feat. Kim Petras)" by Sam Smith...
# Done.
# Searching for "Snooze" by SZA...
# Done.
# Searching for "Lemonade (feat. NAV)" by Internet Money...
# Done.
# Searching for "go" by Cat Burns...
# Done.
# Searching for "Say So" by Doja Cat...
# Searching for "Speed Drive (From Barbie The Album)" by Charli XCX...
# Done.
# Searching for "Last Last" by Burna Boy...
# Searching for "People" by Libianca...
# Done.
# Searching for "Players" by Coi Leray...
# Done.
# Searching for "Peru" by Fireboy DML...
# Done.
# Searching for "Fair Trade (with Travis Scott)" by Drake...
# Done.
# Searching for "telepatía" by Kali Uchis...
# Done.
# Searching for "10 Things I Hate About You" by Leah Kate...
# Done.
# Searching for "DÁKITI" by Bad Bunny...
# Done.
# Searching for "love nwantiti (ah ah ah)" by CKay...
# Done.
# Searching for "WHATS POPPIN" by Jack Harlow...
# Done.
# Searching for "Finesse" by Pheelz...
# Done.
# Searching for "Sprinter" by Dave...
# Done.
# Searching for "Laugh Now Cry Later (feat. Lil Durk)" by Drake...
# Done.
# Searching for "Peaches (feat. Daniel Caesar & Giveon)" by Justin Bieber...
# Done.
# Searching for "INDUSTRY BABY (feat. Jack Harlow)" by Lil Nas X...
# Done.
# Searching for "Made You Look" by Meghan Trainor...
# Done.
# Searching for "Woman" by Doja Cat...
# Done.
# Searching for "Boy's a liar Pt. 2" by PinkPantheress...
# Done.
# Searching for "DESPECHÁ" by ROSALÍA...
# Done.
# Searching for "Starlight" by Dave...
# Done.
# Searching for "Heartbreak Anniversary" by Giveon...
# Done.
# Searching for "Standing Next to You" by Jung Kook...
# Done.
# Searching for "MONTERO (Call Me By Your Name)" by Lil Nas X...
# Done.
# Searching for "Tití Me Preguntó" by Bad Bunny...
# Done.
# Searching for "Essence (feat. Tems)" by Wizkid...
# Done.
# Searching for "Doja" by Central Cee...
# Done.
# Searching for "Intentions" by Justin Bieber...
# Done.
# Searching for "BILLIE EILISH." by Armani White...
# Done.
# Searching for "Glock In My Lap" by 21 Savage...
# Done.
# Searching for "The Box" by Roddy Ricch...
# Done.
# Searching for "Rover (feat. DTG)" by S1mba...
# Done.
# Searching for "What You Know Bout Love" by Pop Smoke...
# Done.
# Searching for "Tusa" by KAROL G...
# Done.
# /var/folders/s6/ny1859490sj527r3gf8tnfrh0000gn/T/ipykernel_15250/64719398.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   song_df['lyrics'] = lyrics_vector

# %% [markdown]
# # Build LIB Table

# %%
# songs_70s_with_lyrics['Decade'] = "70s"
# songs_80s_with_lyrics['Decade'] = "80s"
# songs_90s_with_lyrics['Decade'] = "90s"
# songs_2000s_with_lyrics['Decade'] = "2000s"
# songs_2010s_with_lyrics['Decade'] = "2010s"
# songs_2020s_with_lyrics['Decade'] = "2020s"

# %%
# Save query results so we don't need to rerun
# songs_70s_with_lyrics.to_csv('data/song_dfs/70s_df.csv')
# songs_80s_with_lyrics.to_csv('data/song_dfs/80s_df.csv')
# songs_90s_with_lyrics.to_csv('data/song_dfs/90s_df.csv')
# songs_2000s_with_lyrics.to_csv('data/song_dfs/2000s_df.csv')
# songs_2010s_with_lyrics.to_csv('data/song_dfs/2010s_df.csv')
# songs_2020s_with_lyrics.to_csv('data/song_dfs/2020s_df.csv')

# %%
songs_70s_with_lyrics = pd.read_csv('data/song_dfs/70s_df.csv').drop('Unnamed: 0', axis=1)
songs_80s_with_lyrics = pd.read_csv('data/song_dfs/80s_df.csv').drop('Unnamed: 0', axis=1)
songs_90s_with_lyrics = pd.read_csv('data/song_dfs/90s_df.csv').drop('Unnamed: 0', axis=1)
songs_2000s_with_lyrics = pd.read_csv('data/song_dfs/2000s_df.csv').drop('Unnamed: 0', axis=1)
songs_2010s_with_lyrics = pd.read_csv('data/song_dfs/2010s_df.csv').drop('Unnamed: 0', axis=1)
songs_2020s_with_lyrics = pd.read_csv('data/song_dfs/2020s_df.csv').drop('Unnamed: 0', axis=1)

# %%
temp_lib = pd.concat([songs_70s_with_lyrics, songs_80s_with_lyrics, songs_90s_with_lyrics, songs_2000s_with_lyrics, songs_2010s_with_lyrics, songs_2020s_with_lyrics])

# %%
SONG_LIB = temp_lib.rename({'track.artists':'artist'}, axis = 1).drop('track.id', axis=1)

SONG_LIB.index.name = 'song_id'

SONG_LIB
# Out:
#                  artist  track.duration_ms               track.name  \
# song_id
# 0         Fleetwood Mac             257800   Dreams - 2004 Remaster
# 1            Elton John             377093              Tiny Dancer
# 2            Billy Joel             214240                   Vienna
# 3               The Who             300400             Baba O'Riley
# 4        Gerry Rafferty             267773      Right Down the Line
# ...                 ...                ...                      ...
# 145           21 Savage             193591          Glock In My Lap
# 146         Roddy Ricch             196652                  The Box
# 147               S1mba             167916        Rover (feat. DTG)
# 148           Pop Smoke             160000  What You Know Bout Love
# 149             KAROL G             201920                     Tusa
#
#          track.popularity  danceability  energy  key  loudness  mode  \
# song_id
# 0                      86         0.828   0.492    0    -9.744     1
# 1                      78         0.414   0.428    0   -11.097     1
# 2                      84         0.532   0.495   10    -6.662     1
# 3                      76         0.489   0.724    5    -8.367     1
# 4                      74         0.783   0.322    0   -15.091     1
# ...                   ...           ...     ...  ...       ...   ...
# 145                    83         0.847   0.733   10    -6.439     0
# 146                    83         0.896   0.586   10    -6.687     0
# 147                    69         0.613   0.624   11    -6.660     0
# 148                    79         0.709   0.548   10    -8.493     1
# 149                    70         0.799   0.701    2    -3.272     1
#
#          speechiness  acousticness  instrumentalness  liveness  valence  \
# song_id
# 0             0.0276       0.06440          0.004280    0.1280    0.789
# 1             0.0278       0.38200          0.000243    0.1480    0.282
# 2             0.0343       0.65900          0.000000    0.0754    0.308
# 3             0.0352       0.31300          0.185000    0.2870    0.150
# 4             0.0343       0.21300          0.002430    0.1140    0.770
# ...              ...           ...               ...       ...      ...
# 145           0.1600       0.00574          0.000010    0.1510    0.202
# 146           0.0559       0.10400          0.000000    0.7900    0.642
# 147           0.2060       0.49600          0.000000    0.2830    0.803
# 148           0.3530       0.65000          0.000002    0.1330    0.543
# 149           0.2820       0.30900          0.000074    0.0514    0.607
#
#            tempo  time_signature  \
# song_id
# 0        120.151               4
# 1        145.075               4
# 2        124.936               4
# 3        117.292               4
# 4        128.226               4
# ...          ...             ...
# 145      130.029               4
# 146      116.971               4
# 147       62.948               5
# 148       83.995               4
# 149      100.946               4
#
#                                                     genres  \
# song_id
# 0        ['album rock', 'classic rock', 'rock', 'soft r...
# 1        ['glam rock', 'mellow gold', 'piano rock', 'ro...
# 2        ['album rock', 'classic rock', 'heartland rock...
# 3        ['album rock', 'british invasion', 'classic ro...
# 4        ['art rock', 'classic rock', 'folk rock', 'mel...
# ...                                                    ...
# 145                      ['atl hip hop', 'hip hop', 'rap']
# 146                         ['melodic rap', 'rap', 'trap']
# 147                                          ['afroswing']
# 148                              ['brooklyn drill', 'rap']
# 149      ['reggaeton', 'reggaeton colombiano', 'trap la...
#
#                                                     lyrics Decade
# song_id
# 0        Stevie Nicks - Edge of Seventeen ( Remaster)\n...    70s
# 1        \nBlue jean baby, L.A. lady\nSeamstress for th...    70s
# 2        \nSlow down, you crazy child\nYou're so ambiti...    70s
# 3        \nOut here in the fields, I fight for my meals...    70s
# 4        \nYou know I need your love\nYou've got that h...    70s
# ...                                                    ...    ...
# 145      \nY'all niggas stop playin', nigga\nY'all nigg...  2020s
# 146      \nPullin' out the coupe at the lot\nTold 'em f...  2020s
# 147      \nShorty said she coming with her bredrins\n'C...  2020s
# 148      \nUh\n\nShawty go joggin' every morning (Every...  2020s
# 149      \n\n¿Qué pasa contigo? Dímelo\nRrr!\nO-O-Ovy o...  2020s
#
# [900 rows x 19 columns]

# %%
# More regex:
# Check if lyrics contain 'Remaster' or 'Remastered' or 'feat.' to remove text where it is an arbitrary list of songs
# Check if lyrics are less than 20 chars long
# Remove some figures from other languages 

SONG_LIB = SONG_LIB[~SONG_LIB['lyrics'].str.contains(r'übersehen', case=False, na=False)]
SONG_LIB = SONG_LIB[~SONG_LIB['lyrics'].str.contains(r'zurück', case=False, na=False)]
SONG_LIB = SONG_LIB[~SONG_LIB['lyrics'].str.contains(r'ọmọ', case=False, na=False)]
SONG_LIB = SONG_LIB[~SONG_LIB['lyrics'].str.contains(r'şöyle', case=False, na=False)]
SONG_LIB = SONG_LIB[~SONG_LIB['lyrics'].str.contains(r'在', case=False, na=False)]
SONG_LIB = SONG_LIB[~SONG_LIB['lyrics'].str.contains(r'Remaster|Remastered|feat.', case=False, na=False)]
SONG_LIB = SONG_LIB[SONG_LIB['lyrics'].str.len() >= 20]


# Reset index
SONG_LIB.reset_index(drop=True, inplace=True)

# %%
SONG_LIB
# Out:
#              artist  track.duration_ms  \
# 0        Elton John             377093
# 1        Billy Joel             214240
# 2           The Who             300400
# 3    Gerry Rafferty             267773
# 4        Elton John             281613
# ..              ...                ...
# 647       21 Savage             193591
# 648     Roddy Ricch             196652
# 649           S1mba             167916
# 650       Pop Smoke             160000
# 651         KAROL G             201920
#
#                                             track.name  track.popularity  \
# 0                                          Tiny Dancer                78
# 1                                               Vienna                84
# 2                                         Baba O'Riley                76
# 3                                  Right Down the Line                74
# 4    Rocket Man (I Think It's Going To Be A Long, L...                82
# ..                                                 ...               ...
# 647                                    Glock In My Lap                83
# 648                                            The Box                83
# 649                                  Rover (feat. DTG)                69
# 650                            What You Know Bout Love                79
# 651                                               Tusa                70
#
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.414   0.428    0   -11.097     1       0.0278       0.38200
# 1           0.532   0.495   10    -6.662     1       0.0343       0.65900
# 2           0.489   0.724    5    -8.367     1       0.0352       0.31300
# 3           0.783   0.322    0   -15.091     1       0.0343       0.21300
# 4           0.601   0.532   10    -9.119     1       0.0286       0.43300
# ..            ...     ...  ...       ...   ...          ...           ...
# 647         0.847   0.733   10    -6.439     0       0.1600       0.00574
# 648         0.896   0.586   10    -6.687     0       0.0559       0.10400
# 649         0.613   0.624   11    -6.660     0       0.2060       0.49600
# 650         0.709   0.548   10    -8.493     1       0.3530       0.65000
# 651         0.799   0.701    2    -3.272     1       0.2820       0.30900
#
#      instrumentalness  liveness  valence    tempo  time_signature  \
# 0            0.000243    0.1480    0.282  145.075               4
# 1            0.000000    0.0754    0.308  124.936               4
# 2            0.185000    0.2870    0.150  117.292               4
# 3            0.002430    0.1140    0.770  128.226               4
# 4            0.000006    0.0925    0.342  136.576               4
# ..                ...       ...      ...      ...             ...
# 647          0.000010    0.1510    0.202  130.029               4
# 648          0.000000    0.7900    0.642  116.971               4
# 649          0.000000    0.2830    0.803   62.948               5
# 650          0.000002    0.1330    0.543   83.995               4
# 651          0.000074    0.0514    0.607  100.946               4
#
#                                                 genres  \
# 0    ['glam rock', 'mellow gold', 'piano rock', 'ro...
# 1    ['album rock', 'classic rock', 'heartland rock...
# 2    ['album rock', 'british invasion', 'classic ro...
# 3    ['art rock', 'classic rock', 'folk rock', 'mel...
# 4    ['glam rock', 'mellow gold', 'piano rock', 'ro...
# ..                                                 ...
# 647                  ['atl hip hop', 'hip hop', 'rap']
# 648                     ['melodic rap', 'rap', 'trap']
# 649                                      ['afroswing']
# 650                          ['brooklyn drill', 'rap']
# 651  ['reggaeton', 'reggaeton colombiano', 'trap la...
#
#                                                 lyrics Decade
# 0    \nBlue jean baby, L.A. lady\nSeamstress for th...    70s
# 1    \nSlow down, you crazy child\nYou're so ambiti...    70s
# 2    \nOut here in the fields, I fight for my meals...    70s
# 3    \nYou know I need your love\nYou've got that h...    70s
# 4    \nShe packed my bags last night pre-flight\nZe...    70s
# ..                                                 ...    ...
# 647  \nY'all niggas stop playin', nigga\nY'all nigg...  2020s
# 648  \nPullin' out the coupe at the lot\nTold 'em f...  2020s
# 649  \nShorty said she coming with her bredrins\n'C...  2020s
# 650  \nUh\n\nShawty go joggin' every morning (Every...  2020s
# 651  \n\n¿Qué pasa contigo? Dímelo\nRrr!\nO-O-Ovy o...  2020s
#
# [652 rows x 19 columns]

# %%
SONG_LIB.dtypes
# Out:
# artist                object
# track.duration_ms      int64
# track.name            object
# track.popularity       int64
# danceability         float64
# energy               float64
# key                    int64
# loudness             float64
# mode                   int64
# speechiness          float64
# acousticness         float64
# instrumentalness     float64
# liveness             float64
# valence              float64
# tempo                float64
# time_signature         int64
# genres                object
# lyrics                object
# Decade                object
# dtype: object

# %%
import os

# Write each decade as a text file to the 'decades' directory
for decade in SONG_LIB.Decade.unique():
    decade_text = ''
    decade_df = SONG_LIB.query("Decade == @decade")

    file_path = os.path.join("data", "decades", f"{decade}.txt")
    os.makedirs(os.path.dirname(file_path), exist_ok=True)

    with open(file_path, 'w') as outfile:
        for i in range(len(decade_df)):
            lyrics = str(decade_df.iloc[i]['lyrics'])
            track = decade_df.iloc[i]['track.name']
            artist = decade_df.iloc[i]['artist']

            lyrics = f'\n\n[Trackname: {track}] [Artist: {artist}]\n' + lyrics
            outfile.write(lyrics)

    print(f'Wrote playlist {decade} to file {file_path}')
# Out:
# Wrote playlist 70s to file data/decades/70s.txt
# Wrote playlist 80s to file data/decades/80s.txt
# Wrote playlist 90s to file data/decades/90s.txt
# Wrote playlist 2000s to file data/decades/2000s.txt
# Wrote playlist 2010s to file data/decades/2010s.txt
# Wrote playlist 2020s to file data/decades/2020s.txt

# %%
LIB = SONG_LIB.groupby('Decade').agg({
    'danceability':'mean',
    'energy':'mean',
    'loudness':'mean',
    'speechiness':'mean',
    'acousticness':'mean',
    'instrumentalness':'mean',
    'liveness':'mean',
    'valence':'mean',
    'tempo':'mean'
}).reset_index()

# %%
LIB['source_file_path'] = LIB.Decade.apply(lambda x: f'data/decades/{x}.txt')
LIB['song_regex'] = r'\[Trackname:\s[^\]]+\]\s\[Artist:\s[^\]]+\]'
#LIB['song_regex'] = '\[Trackname:\s[^\]]+\]'

LIB.index.name = 'decade_id'

# %%
LIB['document_length'] = LIB['source_file_path'].apply(lambda path: len(open(path, 'r').read()))

# %%
LIB
# Out:
#           Decade  danceability    energy   loudness  speechiness  \
# decade_id
# 0          2000s      0.593643  0.760881  -5.696056     0.067888
# 1          2010s      0.634008  0.673200  -6.217608     0.064475
# 2          2020s      0.675517  0.619595  -6.329922     0.079997
# 3            70s      0.571966  0.611978 -10.020067     0.053069
# 4            80s      0.618161  0.681151  -9.199699     0.048652
# 5            90s      0.572694  0.718213  -7.624593     0.048655
#
#            acousticness  instrumentalness  liveness   valence       tempo  \
# decade_id
# 0              0.098199          0.037857  0.182493  0.537506  124.994357
# 1              0.166805          0.022972  0.177836  0.461078  118.889683
# 2              0.284910          0.009680  0.183418  0.542036  122.167810
# 3              0.310864          0.032363  0.171034  0.632270  122.576472
# 4              0.177320          0.023871  0.155342  0.664387  119.188785
# 5              0.110941          0.060286  0.175645  0.585344  115.385731
#
#                  source_file_path  \
# decade_id
# 0          data/decades/2000s.txt
# 1          data/decades/2010s.txt
# 2          data/decades/2020s.txt
# 3            data/decades/70s.txt
# 4            data/decades/80s.txt
# 5            data/decades/90s.txt
#
#                                             song_regex  document_length
# decade_id
# 0          \[Trackname:\s[^\]]+\]\s\[Artist:\s[^\]]+\]           216931
# 1          \[Trackname:\s[^\]]+\]\s\[Artist:\s[^\]]+\]           195291
# 2          \[Trackname:\s[^\]]+\]\s\[Artist:\s[^\]]+\]           212348
# 3          \[Trackname:\s[^\]]+\]\s\[Artist:\s[^\]]+\]           127933
# 4          \[Trackname:\s[^\]]+\]\s\[Artist:\s[^\]]+\]           151152
# 5          \[Trackname:\s[^\]]+\]\s\[Artist:\s[^\]]+\]           174393

# %% [markdown]
# # Parse Decades into CORPUS

# %%
source_file_list = sorted(glob(f"data/decades/*.*"))

source_file_list
# Out:
# ['data/decades/2000s.txt',
#  'data/decades/2010s.txt',
#  'data/decades/2020s.txt',
#  'data/decades/70s.txt',
#  'data/decades/80s.txt',
#  'data/decades/90s.txt']

# %%
nltk_resources = [
    'tokenizers/punkt', 
    'taggers/averaged_perceptron_tagger', 
    'corpora/stopwords', 
    'help/tagsets'
]
for rsc in nltk_resources:
    try:
        nltk.data.find(rsc)
    except IndexError:
        nltk.download(rsc)

# %%
OHCO = ['decade_id', 'song_num', 'stanza_num', 'line_num', 'token_num']

# %%
def parse_decade(decade_id: int, decade_name: str, song_regex: str):
    with open(f'data/decades/{decade_name}.txt', 'r', encoding='utf-8-sig') as file:
        lines = file.readlines()
    LINES = pd.DataFrame({'line_str': lines}, columns=['line_str'])
    LINES.index.name = 'line_num'
    LINES['line_str'] = LINES['line_str'].str.strip()

    chap_pat = LIB.iloc[0].song_regex
    chap_lines = LINES['line_str'].str.match(chap_pat, case=False)

    LINES.loc[chap_lines, 'song_num'] = range(sum(chap_lines))
    LINES['song_num'] = LINES['song_num'].ffill()

    LINES = LINES.dropna(subset=['song_num'])
    LINES = LINES.loc[~chap_lines]
    LINES['song_num'] = LINES['song_num'].astype(int)

    SONGS = LINES.groupby('song_num')['line_str'].apply('\n'.join).to_frame('song_str')
    SONGS['song_str'] = SONGS['song_str'].str.strip()

    stanza_pat = r'\n\n+'
    STANZAS = SONGS['song_str'].str.split(stanza_pat, expand=True).stack().to_frame('stanza_str').sort_index()
    STANZAS.index.names = ['song_num', 'stanza_num']

    STANZAS['stanza_str'] = STANZAS['stanza_str'].str.strip()
    STANZAS = STANZAS[~STANZAS['stanza_str'].str.match(r'^\s*$')]

    line_pat = r'\n'
    LINES = STANZAS['stanza_str'].str.split(line_pat, expand=True).stack().to_frame('line_str')
    LINES.index.names = ['song_num', 'stanza_num', 'line_num']

    LINES = LINES[~LINES['line_str'].str.match(r'^\s*$')]
    LINES['line_str'] = LINES['line_str'].str.strip()

    TOKENS = LINES['line_str'].apply(lambda x: pd.Series(nltk.pos_tag(nltk.WhitespaceTokenizer().tokenize(x))))\
        .stack().to_frame('pos_tuple')
    TOKENS.index.names = ['song_num', 'stanza_num', 'line_num', 'token_num']

    TOKENS = pd.concat({decade_id: TOKENS}, names=['decade_id'])

    return TOKENS

# %%
decades = []

for decade_id in LIB.index:
    decades.append(parse_decade(decade_id, LIB.iloc[decade_id].Decade, LIB.iloc[decade_id].song_regex))

# %%
CORPUS = pd.concat(decades).sort_index()

CORPUS['pos'] = CORPUS.pos_tuple.apply(lambda x: x[1])
CORPUS['token_str'] = CORPUS.pos_tuple.apply(lambda x: x[0])
CORPUS['term_str'] = CORPUS.token_str.str.lower().str.replace(r"\W+", "", regex=True)
CORPUS['pos_group'] = CORPUS.pos.str[:2]

# %%
CORPUS = CORPUS[CORPUS.term_str != '']
CORPUS
# Out:
#                                                        pos_tuple  pos  \
# decade_id song_num stanza_num line_num token_num
# 0         0        0          0        0           (Here's, NNP)  NNP
#                                        1               (the, DT)   DT
#                                        2            (thing,, NN)   NN
#                                        3               (we, PRP)  PRP
#                                        4          (started, VBD)  VBD
# ...                                                          ...  ...
# 5         107      9          2        1            (y'all, PRP)  PRP
#                                        2             (deep, VBP)  VBP
#                               3        0             (Y'all, DT)   DT
#                                        1              (are, VBP)  VBP
#                                        2            (crazy,, JJ)   JJ
#
#                                                  token_str term_str pos_group
# decade_id song_num stanza_num line_num token_num
# 0         0        0          0        0            Here's    heres        NN
#                                        1               the      the        DT
#                                        2            thing,    thing        NN
#                                        3                we       we        PR
#                                        4           started  started        VB
# ...                                                    ...      ...       ...
# 5         107      9          2        1             y'all     yall        PR
#                                        2              deep     deep        VB
#                               3        0             Y'all     yall        DT
#                                        1               are      are        VB
#                                        2            crazy,    crazy        JJ
#
# [207176 rows x 5 columns]

# %%
VOCAB = CORPUS.term_str.value_counts().to_frame('n').sort_index()
VOCAB.index.name = 'term_str'
VOCAB['n_chars'] = VOCAB.index.str.len()    
VOCAB['p'] = VOCAB.n/VOCAB.n.sum()
VOCAB['i'] = -np.log2(VOCAB.p)
VOCAB['max_pos'] = CORPUS[['term_str', 'pos']].value_counts()\
    .unstack(fill_value=0)\
    .idxmax(1)
VOCAB['max_pos_group'] = CORPUS[['term_str','pos_group']].value_counts()\
    .unstack(fill_value=0)\
    .idxmax(1)

# %%
from nltk.stem.porter import PorterStemmer
stemmer1 = PorterStemmer()
VOCAB['stem_porter'] = VOCAB.apply(lambda x: stemmer1.stem(x.name), 1)

# %%
sw = pd.DataFrame(nltk.corpus.stopwords.words('english'), columns=['term_str'])
sw = sw.reset_index().set_index('term_str')
sw.columns = ['dummy']
sw.dummy = 1

VOCAB['stop'] = VOCAB.index.map(sw.dummy)
VOCAB['stop'] = VOCAB['stop'].fillna(0).astype('int')

# %%
VOCAB
# Out:
#            n  n_chars         p          i max_pos max_pos_group stem_porter  \
# term_str
# 1          2        1  0.000010  16.660497      CD            CD           1
# 10k        2        3  0.000010  16.660497      CD            CD         10k
# 1k         1        2  0.000005  17.660497      CD            CD          1k
# 1s         1        2  0.000005  17.660497      CD            CD          1s
# 2          3        1  0.000014  16.075535      CD            CD           2
# ...       ..      ...       ...        ...     ...           ...         ...
# è         12        1  0.000058  14.075535     NNP            NN           è
# él         3        2  0.000014  16.075535     NNP            NN          él
# еlla       1        4  0.000005  17.660497      IN            IN        еlla
# еsta       1        4  0.000005  17.660497     VBZ            VB        еsta
# еyes       1        4  0.000005  17.660497      FW            FW         еye
#
#           stop
# term_str
# 1            0
# 10k          0
# 1k           0
# 1s           0
# 2            0
# ...        ...
# è            0
# él           0
# еlla         0
# еsta         0
# еyes         0
#
# [8975 rows x 8 columns]

# %% [markdown]
# ### Write Core Tables to CSV

# %%
CORPUS.columns
# Out:
# Index(['pos_tuple', 'pos', 'token_str', 'term_str', 'pos_group'], dtype='object')

# %%
LIB.to_csv('data/core_tables/LIB.csv')
CORPUS.to_csv('data/core_tables/CORPUS.csv')
VOCAB.to_csv('data/core_tables/VOCAB.csv')
